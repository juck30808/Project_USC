# %% [markdown]
# # (1) Read data
# pip install jieba

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#設定matplot可以直接在Notebook中畫出，不需要執行plt.plot()
# %matplotlib inline 

# 設定 Seaborn 的顯示樣式
# https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.set_style('whitegrid')

#載入資料
data = pd.read_csv("data/Op_Dcard_markeup.csv")
data.head()
# Out:
#           ID                                 title  \
# 0  235022153  ❄️聖誕妝容推薦❄️ 準備漂亮過節讓你 bling bling 惹人愛！
# 1  235025010               #吐槽大會 那些我2021絕對不會購入的東西🌚
# 2  235026845                         毛孔人必備的幾樣小可愛們✍
# 3  235025318                            舊款焦糖拿鐵的替代品
# 4  235029187                 #分享 約會必備桃花眼妝💐-完美日記錦鯉盤
#
#                                              content  \
# 0  這週就是🎄聖誕節惹⛄️\n各位卡友們餐廳跟交換禮物都準備好了！\n現在應該是萬事俱備 只欠東...
# 1  Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下 \n所以...
# 2  身為毛孔人，只要能讓毛孔縮小一咪咪\n都是讓人值得開心的事情阿～😙\n自己除了有固定使用針對...
# 3  在康是美快打烊的時候 衝了一波他們的99元唇膏\n也不想造成店員困擾 於是也沒試色拿了一隻顏...
# 4  哈囉大家好這裡是最近很高產的兔子🐰\n之後可能就不會這麼常發文了\n想趕快把手邊能分享的產品...
#
#                                              excerpt  \
# 0  這週就是聖誕節惹️，各位卡友們餐廳跟交換禮物都準備好了！，現在應該是萬事俱備 只欠東風，是聖...
# 1  Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下，所以今天...
# 2  身為毛孔人，只要能讓毛孔縮小一咪咪，都是讓人值得開心的事情阿～自己除了有固定使用針對毛孔的保...
# 3  在康是美快打烊的時候 衝了一波他們的99元唇膏，也不想造成店員困擾 於是也沒試色拿了一隻顏色...
# 4  哈囉大家好這裡是最近很高產的兔子，之後可能就不會這麼常發文了，想趕快把手邊能分享的產品分享出...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2020-12-21T07:07:47.084Z  2020-12-21T10:13:21.728Z        美妝     makeup
# 1  2020-12-21T14:45:24.926Z  2020-12-21T14:45:24.926Z        美妝     makeup
# 2  2020-12-22T00:38:00.446Z  2020-12-22T00:38:00.446Z        美妝     makeup
# 3  2020-12-21T15:29:36.622Z  2020-12-21T15:29:36.622Z        美妝     makeup
# 4  2020-12-22T08:35:30.926Z  2020-12-22T08:36:44.262Z        美妝     makeup
#
#   gender  topics
# 0      D      NaN
# 1      F      NaN
# 2      F      NaN
# 3      F      NaN
# 4      F      NaN

# %%
data.shape  #type(pandas.core.frame.DataFrame)
# Out:
# (88, 10)

# %% [markdown]
# # (2) 格式轉換
#
# - transform Type(pandas.core.series.Series) to list
# - transform Type(list) to str
# - addition: https://blog.csdn.net/Zx_whu/article/details/61926655

# %%
dt_list = data['content'].tolist()   # transform Type(pandas.core.series.Series) to list
#dt_list[0]  #Content 第一篇文章
#dt_list[1]  #Content 第二篇文章
dt_list[87]    #最後一篇文章 #type(str)
# Out:
�單的\n尤其現在冬季，因為疫情關係公眾場合要戴口罩\n基本上我都是妝前乳＋粉餅，再配上美唇油就完工\nFIT ME反孔妝前乳是我近期愛將，毛孔的柔焦效果很不錯\n而且也不會跟後面的底妝有打架或是起屑的問題\n使用後毛孔有被填補撫平，臉上的油光也有被消去\n是呈現微霧面的感覺\n⚠以下有坑疤毛孔使用前後對比圖，有圖慎入喔～\nhttps://i.imgur.com/P3Y6pEU.jpg\n我自己妝前如果有用這條，除了縮毛孔有感，控油力也足夠，持妝度比較好\n不容易脫妝斑駁，整體來說我覺得蠻喜歡的\n偶爾發懶也會直接擦上這條就出門，讓氣色不那麼糟\nhttps://i.imgur.com/IM9HhMY.jpg\n附上近期上妝的照片，有使用粉餅輕輕壓過整臉\n再上唇膏就是有氣色的日常妝容\n就算賴床十分鐘也可以搞定出門XD\n \n以上分享給大家囉！祝福大家年尾都過得順心～在康是美快打烊的時候 衝了一波他們的99元唇膏\n也不想造成店員困擾 於是也沒試色拿了一隻顏色看起來滿美的solone 經典極癮唇膏203就結帳\n沒想到挖到寶了🤩\nhttps://i.imgur.com/8vvwMLR.jpg\n焦糖拿鐵新版的顏色我真的沒有很愛 整體偏紅\n還是比較喜歡舊的 所以一直沒丟掉即便用到只剩一點點\n而solone 經典極癮唇膏203，照片上雖然不明顯，但跟舊款焦糖拿鐵是幾乎一模一樣！\n而且我覺得滋潤程度比舊款好跟新款差不多👍\n現在找到替代品了 舊款終於可以壽終正寢哈囉大家好這裡是最近很高產的兔子🐰\n之後可能就不會這麼常發文了\n想趕快把手邊能分享的產品分享出來！\n\n先上首圖\nhttps://i.imgur.com/x1iGu8E.jpg\n\n❗️此為中國彩妝，介意者勿購買或攻擊❗️\n❗️此為中國彩妝，介意者勿購買或攻擊❗️\n❗️此為中國彩妝，介意者勿購買或攻擊❗️\n很重要所以說三遍 不希望看到留言區吵架！\n\n我真的超級喜歡這個眼妝的(⁎⁍̴̛ᴗ⁍̴̛⁎)\n那就廢話不多說趕緊分享吧！\n-\nhttps://i.imgur. ...

# %% [markdown]
# # (3) Jeiba 語句分析
#
# - https://github.com/ldkrsi/jieba-zh_TW
#
# jieba.cut生成的是一个生成器，generator，也就是可以通过for循环来取里面的每一个词。
# - 全模式: 把句子中所有的可以成詞的詞語都斷出来
# - jieba.cut(sentence, cut_all=True)
# - 精確模式 : 將句子最精確的切開，適合文本分析
# - jieba.cut(sentence, cut_all=False)
# - 搜索引擎模式: 在精確模式的基礎上，對長的詞語再次切分，提高召回率
# - jieba.cut_for_search(sentence)
#
# jieba.lcut 直接生成的就是一个list
# - jieba.lcut(news)

# %%
import jieba
import jieba.analyse

jieba.load_userdict('data/usedict.txt')   #adjust
jieba.add_word("萬事俱備")                  #adjust (quick)

news = dt_str
seg_list = jieba.lcut(news)
print(seg_list)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/93/m9lwmw9s2xn4kcmssn37ztxc0000gn/T/jieba.cache
# Loading model cost 0.492 seconds.
# Prefix dict has been built succesfully.
ard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '235017343', '\n', '等等', '！', '不知不覺', '就', '找', '了', '好多', '！', '！', '\n', '板上', '的', '卡友', '都', '太', '優秀', '了', '～', '\n', '看來', '年末', '真的', '是局', '很多', '😍', '（', '覺得', '羨慕', '）', '\n', '宜', '用心', '打扮', '！', '\n', '\n', '當然', '也', '有', '主題', '系列', '\n', '今晚', '你', '要蜜', '🍑', '還是', '🦌', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '235006917', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '234994219', '\n', '蜜桃', '帽', '跟', '鹿角', '髮箍', '都', '超', '加分', '耶', '！', '可愛', '到', '不行', '～', '\n', '看到', '這邊', '大家', '應該', '都', '對', '自己', '的', '聖誕', '妝容', '有些', '想法', '了', '吧', '😉', '\n', '期待', '大家', '有', '個', '美好', '的', '聖誕節', '夜晚', '！', '🎅', '\n', '\n', '再', '加碼', '幾', '個', '聖誕', '限量', '商品', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '235004906', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '235018533', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', '.', 'tw', '/', 'f', '/', 'makeup', '/', 'p', '/', '235018327', '\n', 'https', ':', '/', '/', 'www', '.', 'dcard', ...

# %%
tags = jieba.analyse.extract_tags(news, topK=20, withWeight=True)
for tag in tags:
    print('tf-idf:', round(tag[1],2),'| word:', tag[0])
# Out:
# tf-idf: 0.28 | word: https
# tf-idf: 0.25 | word: com
# tf-idf: 0.24 | word: imgur
# tf-idf: 0.24 | word: jpg
# tf-idf: 0.08 | word: 沒有
# tf-idf: 0.07 | word: 因為
# tf-idf: 0.07 | word: 產品
# tf-idf: 0.06 | word: 覺得
# tf-idf: 0.06 | word: 還是
# tf-idf: 0.06 | word: 保養
# tf-idf: 0.05 | word: 比較
# tf-idf: 0.05 | word: 真的
# tf-idf: 0.04 | word: 皮膚
# tf-idf: 0.04 | word: 保養品
# tf-idf: 0.04 | word: 分享
# tf-idf: 0.04 | word: 保濕
# tf-idf: 0.04 | word: 感覺
# tf-idf: 0.04 | word: 有點
# tf-idf: 0.03 | word: 精華
# tf-idf: 0.03 | word: 開始

# %%
# 統計詞的出現次數
words = {}
for str in strs:
    if str in words:
        words[str] += 1
    else:
        words[str] = 1   
# for key, value in words.items():
#     print(key, value)
    
# 排序
sorted_keys = sorted(words, key=words.get, reverse=True)
for key in sorted_keys:
    d = {key: words[key]}
    print(key, words[key])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-282c95da0e8c> in <module>
#       1 # 統計詞的出現次數
#       2 words = {}
# ----> 3 for str in strs:
#       4     if str in words:
#       5         words[str] += 1
#
# NameError: name 'strs' is not defined

# %% [markdown]
# ### 統計詞性

# %% [markdown]
# ### 詞性分析

# %%
import jieba
import jieba.posseg as pseg
words = pseg.cut(dt)
for word, flag in words:
    print('%s %s' % (word, flag))
