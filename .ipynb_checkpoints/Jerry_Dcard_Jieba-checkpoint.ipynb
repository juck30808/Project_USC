# %%
#pip install jieba

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#matplot可以直接在Notebook中畫出，不需要執行plt.plot()
# %matplotlib inline 
sns.set_style('whitegrid')

# %%
data = pd.read_csv("data/Dcard_makeup100.csv")
data.head(3)
# Out:
#           id                             title  \
# 0  229872268            #圖 #混合肌 肌膚檢測與簡單保養分享 ：）
# 1  229872246  #開箱 #試色 伊麗莎白雅頓 完美紐約超水潤唇膏-亞洲限定12色
# 2  229872047                 旁氏毛穴淨白美肌淨顏卸妝油沒賣了嗎
#
#                                              content  \
# 0  雖然本身不是什麼保養專家，但自己也保養了很多年，所以想說跟大家分享分享：）\n\n我是混合肌...
# 1  （廢話很多）\n我接觸化妝時間大概半年（只有蜜粉、眉毛，近一兩個月才開始嘗試眼妝、唇妝）\n...
# 2  旁氏的這一款是不是都沒在賣了？\n跑了台中高雄的寶雅跟康是美都沒了\n屈臣氏好像本來就沒在賣...
#
#                                              excerpt  \
# 0  雖然本身不是什麼保養專家，但自己也保養了很多年，所以想說跟大家分享分享：），我是混合肌膚，夏...
# 1  （廢話很多），我接觸化妝時間大概半年（只有蜜粉、眉毛，近一兩個月才開始嘗試眼妝、唇妝），所以...
# 2  旁氏的這一款是不是都沒在賣了？跑了台中高雄的寶雅跟康是美都沒了，屈臣氏好像本來就沒在賣了？寶...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2018-10-17T18:14:00.235Z  2018-10-17T18:17:49.864Z        美妝     makeup
# 1  2018-10-17T18:08:25.507Z  2018-10-17T18:11:28.855Z        美妝     makeup
# 2  2018-10-17T17:30:37.791Z  2018-10-17T17:30:37.791Z        美妝     makeup
#
#   gender  topics
# ...

# %% [markdown]
# ## 1.transform Type
#
# - transform Type(pandas.core.series.Series) to list

# %%
type(data['content'])
# Out:
# pandas.core.series.Series

# %%
dt_list = data['content'].tolist()   # transform Type(pandas.core.series) to list

for i in range(len(dt_list)):
    print(dt_list[i])
    print('============================================')
# Out:
# 雖然本身不是什麼保養專家，但自己也保養了很多年，所以想說跟大家分享分享：）
#
# 我是混合肌膚，夏天稍微偏油一點。冬天當然就是剛剛好的肌膚啦：）
# 很多人都以為肌膚會出油原因是「不夠保濕」，但要告訴大家一個悲慘的事實，肌膚會出油是「天生的」所以要回家問你媽媽～
#
# 我們的皮脂腺本身就會分泌油脂，不會因為你多擦了比較保濕的面霜他就不出油，根本是兩回事的啦！詳細的成因可以看這篇文章：https://www.medpartner.club/oil-water-balance-myth/
#
# 教大家簡單的做肌膚檢測～ 是皮膚科醫生分享給我的，我覺得很簡單也很有用，當然會隨著季節有所不同，有助於大家挑適合自己的保養品跟彩妝品:)) ☺️☺️☺️
#
# 1- 晚上用適量的洗面乳洗臉完後，不擦保養品去睡覺。
# 2- 早上觀察自己出油的部位來判斷，大概分五種！
#
# a . 剛剛好，不油也不乾 > 恭喜你！萬人稱羨的中性肌
# b. 全臉很乾！> 好啦就是乾性肌，小心細紋跟斑點 QQ
# c. 全臉很油！> 那就是油性肌，要注重清潔，小心痘痘粉刺問題～
# d. 兩頰乾燥、T字部位出油 > 混合肌偏乾肌，保養注意分區保養（分兩頰跟T字）
# c. 兩頰偏油、T字部位出油 > 混和偏油性肌，保養注意分區保養（分兩頰跟T字）
#
# -
# 保養的第一步驟：清潔
# ・卸妝跟洗臉 （洗臉是用MUJI的保濕洗面乳，就不特別介紹囉）
#
# 歐舒丹 蠟菊卸妝油 NT$1280 🌼🌼
# 純植物油的卸妝油，比較不容易有粉刺問題！
# （用植村秀的狂長粉刺 - - ) 我自己很喜歡這款的味道，卸妝起來真的很放鬆。
# 以專櫃卸妝來說CP值覺得很高，而且卸除力優秀～
#
# http://i.imgur.com/AOCKs8K.jpg
#
#
# ・化妝水 > 精華液  > 沒錯我就擦這樣！
# http://i.imgur.com/4vlJec4.jpg
#
# （由右到左）
#
# 1- 歐舒丹 蠟菊精華凝露 NT$1280
#
# 這款化妝水我個人真的很推，在櫃上試用之後就愛上了 ❤️
# 質地雖然偏濃稠，我都是不用化妝棉直接擦在肌膚上，稍微按摩讓肌膚吸收。完全不會粘，而且沒有酒精。
# ...

# %% [markdown]
# # 2.Jeiba Sentence Analysis
#
# jieba.cut 生成 generator 循環取出關鍵字
# - jieba.cut(sentence, cut_all=True)  全模式:   將句子中所有的可以成詞的詞語都斷出来
# - jieba.cut(sentence, cut_all=False) 精確模式: 將句子最精確的切開，適合文本分析
# - jieba.cut_for_search(sentence)     搜索引擎: 在精確模式的基礎上，對長的詞語再次切分，提高 Recall rate.
#
# jieba.lcut 生成 list
# - jieba.lcut(news)
#
# - https://github.com/ldkrsi/jieba-zh_TW
# - https://blog.kennycoder.io/2020/02/12/Python-知名Jieba中文斷詞工具教學/

# %%
import jieba
import jieba.analyse

# %%
# 負面關鍵字過濾後
stopWords=[]
remainderWords=[]
jieba.load_userdict('data/usedict.txt')   #adjust
    
with open('data/stopWords.txt','r',encoding='utf-8') as file:
    for w in file.readlines():
        w=w.strip()
        stopWords.append(w)

for i in range(len(dt_list)):
    seg_list = jieba.lcut(dt_list[i],cut_all=False)
    remainderWords = list(filter(lambda a: a not in stopWords and a != '\n', seg_list))
    data['content'][i] = remainderWords
    print(remainderWords)
    print('====================')
    
# 不進行負面關鍵字過濾
# for i in range(1):
#     seg_list = jieba.lcut(dt_list[i])
#     print(seg_list)
#     print('====================')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\CTI110~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.542 seconds.
# Prefix dict has been built successfully.
# C:\Users\CTI110~1\AppData\Local\Temp/ipykernel_11888/1897015057.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['content'][i] = remainderWords
# ...

# %%
data.head(2)
# Out:
#           id                             title  \
# 0  229872268            #圖 #混合肌 肌膚檢測與簡單保養分享 ：）
# 1  229872246  #開箱 #試色 伊麗莎白雅頓 完美紐約超水潤唇膏-亞洲限定12色
#
#                                              content  \
# 0  [本身, 保養, 專家, 但, 也, 保養, 了, 很多年, 想, 說, ）, 是, 混合,...
# 1  [（, 廢話, ）, 我接, 觸化妝, 半年, （, 只有, 蜜粉, 眉毛, 近一, 兩個,...
#
#                                              excerpt  \
# 0  雖然本身不是什麼保養專家，但自己也保養了很多年，所以想說跟大家分享分享：），我是混合肌膚，夏...
# 1  （廢話很多），我接觸化妝時間大概半年（只有蜜粉、眉毛，近一兩個月才開始嘗試眼妝、唇妝），所以...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2018-10-17T18:14:00.235Z  2018-10-17T18:17:49.864Z        美妝     makeup
# 1  2018-10-17T18:08:25.507Z  2018-10-17T18:11:28.855Z        美妝     makeup
#
#   gender  topics
# 0      F      NaN
# 1      F      NaN

# %% [markdown]
# # (4) Jeiba 分佈分析
# - TF-IDF算法 https://zhuanlan.zhihu.com/p/95358646

# %%
dt_list = data['content'].tolist()
dt_str= ''.join(map(str,dt_list))
dt_str  #type string
# Out:
# '[\'本身\', \'保養\', \'專家\', \'但\', \'也\', \'保養\', \'了\', \'很多年\', \'想\', \'說\', \'）\', \'是\', \'混合\', \'夏天\', \'稍微\', \'偏油\', \'冬天\', \'當然\', \'剛剛\', \'好\', \'的\', \'啦\', \'）\', \'人\', \'都\', \'以\', \'為\', \'肌膚會\', \'出油\', \'原因\', \'是\', \'「\', \'不夠\', \'保濕\', \'」\', \'但要\', \'告訴\', \'悲慘\', \'的\', \'事實\', \'肌膚會\', \'出油\', \'是\', \'「\', \'天生\', \'的\', \'」\', \'要\', \'回家\', \'問你媽媽\', \'的\', \'皮脂腺\', \'本身\', \'就\', \'會\', \'分泌\', \'油脂\', \'多\', \'擦\', \'了\', \'比\', \'較\', \'保濕\', \'的\', \'面霜\', \'就\', \'不\', \'出油\', \'根本\', \'是\', \'兩\', \'回事\', \'的\', \'啦\', \'詳細\', \'的\', \'成因\', \'看\', \'這\', \'篇文章\', \'medpartner\', \'club\', \'oil\', \'-\', \'water\', \'-\', \'balance\', \'-\', \'myth\', \'教\', \'簡單\', \'的\', \'做\', \'檢測\', \' \', \'是\', \'科醫生\', \'給我\', \'的\', \'得\', \'很\', \'簡單\', \'也\', \'很\', \'有用\', \'當然會\', \'隨著\', \'季節\', \'有所不同\', \'有助\', \'於\', \'挑\', \'的\', \'保養品\', \'彩妝品\', \')\', \')\', \' \', \'☺\', \'️\', \'☺\', \'️\', \'☺\', \'️\', \'1\', \'-\', \' \', \'晚上\', \'用\', \
# ...

# %%
tags = jieba.analyse.extract_tags(dt_str, topK=30, withWeight=True)
for tag in tags:
    print('tf-idf:', round(tag[1],5),'| word:', tag[0])
# Out:
# tf-idf: 0.06369 | word: 顏色
# tf-idf: 0.06172 | word: 保濕
# tf-idf: 0.05844 | word: 眼影
# tf-idf: 0.04644 | word: 唇膏
# tf-idf: 0.03604 | word: u200d
# tf-idf: 0.03456 | word: 保養
# tf-idf: 0.02851 | word: 痘痘
# tf-idf: 0.02666 | word: 保養品
# tf-idf: 0.02617 | word: 質地
# tf-idf: 0.0237 | word: 試色
# tf-idf: 0.02173 | word: 精華
# tf-idf: 0.02173 | word: 色號
# tf-idf: 0.02132 | word: 粉刺
# tf-idf: 0.02123 | word: 特別
# tf-idf: 0.0209 | word: 味道
# tf-idf: 0.02024 | word: 乾燥
# tf-idf: 0.02024 | word: 價格
# tf-idf: 0.02009 | word: 蜜粉
# tf-idf: 0.01956 | word: 粉底液
# tf-idf: 0.01946 | word: 持久
# tf-idf: 0.01901 | word: 效果
# tf-idf: 0.01879 | word: 面膜
# tf-idf: 0.01876 | word: 化妝水
# tf-idf: 0.0179 | word: 粉底
# tf-idf: 0.01782 | word: 眼皮
# tf-idf: 0.01679 | word: 防曬
# tf-idf: 0.01629 | word: 試試
# tf-idf: 0.01629 | word: 狀況
# tf-idf: 0.01562 | word: 乳液
# tf-idf: 0.01531 | word: 包裝

# %% [markdown]
# # (5) apyori 關聯性分析
# - https://chwang12341.medium.com/machine-learning-關聯分析-apriori演算法-詳細解說啤酒與尿布的背後原理-python實作-scikit-learn一步一步教學-76b7778f8f34
#
# - pip install apyori
# - pip install mlxtend

# %%
data.head(2)
# Out:
#           id                             title  \
# 0  229872268            #圖 #混合肌 肌膚檢測與簡單保養分享 ：）
# 1  229872246  #開箱 #試色 伊麗莎白雅頓 完美紐約超水潤唇膏-亞洲限定12色
#
#                                              content  \
# 0  [本身, 保養, 專家, 但, 也, 保養, 了, 很多年, 想, 說, ）, 是, 混合,...
# 1  [（, 廢話, ）, 我接, 觸化妝, 半年, （, 只有, 蜜粉, 眉毛, 近一, 兩個,...
#
#                                              excerpt  \
# 0  雖然本身不是什麼保養專家，但自己也保養了很多年，所以想說跟大家分享分享：），我是混合肌膚，夏...
# 1  （廢話很多），我接觸化妝時間大概半年（只有蜜粉、眉毛，近一兩個月才開始嘗試眼妝、唇妝），所以...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2018-10-17T18:14:00.235Z  2018-10-17T18:17:49.864Z        美妝     makeup
# 1  2018-10-17T18:08:25.507Z  2018-10-17T18:11:28.855Z        美妝     makeup
#
#   gender  topics
# 0      F      NaN
# 1      F      NaN

# %%
from apyori import apriori

dt = []
for x in range(len(dt_list)):
    dt.append(data['content'][x])

association_rules = apriori(dt, min_support=0.05,   # 總共200筆交易數據，A出現20筆, SUP為 50/200 = 1/4,
                            min_confidence=0.95,    # 兩物品同時出現的條件機率，出現商品A的情況下，出現商品B的機率
                            min_lift=2,            # 數據間的關聯性，正相關>1 : 不相關=1 : 負相關<1
                            max_length=2)
                    
association_results = list(association_rules)
#print(association_results)

for product in association_results:
    pair = product[0] 
    products = [x for x in pair]
    #print(products)
    print("Rule: " + products[0] + " → " + products[1])
    print("Support: " + str(product[1]))
    print("Lift: " + str(product[2][0][3]))
    print("==================================")
# Out:
# Rule: ( → )
# Support: 0.26865671641791045
# Lift: 3.076530612244898
# ...
# Rule: CP → 又
# Support: 0.05472636815920398
# Lift: 3.0
# ...
# Rule: ‍ → ️
# Support: 0.0945273631840796
# Lift: 3.092307692307692
# ...
# Rule: 後 → —
# Support: 0.05472636815920398
# Lift: 2.09375
# ...
# Rule: 」 → 「
# Support: 0.0845771144278607
# Lift: 11.823529411764705
# ...
# Rule: 又 → 不少
# Support: 0.05970149253731343
# Lift: 3.0
# ...
# Rule: 值 → 又
# Support: 0.05970149253731343
# Lift: 3.0
# ...
# Rule: 加強 → 後
# Support: 0.05472636815920398
# Lift: 2.09375
# ...
# Rule: 很快 → 後
# Support: 0.05472636815920398
# Lift: 2.09375
# ...
# Rule: 用 → 很快
# Support: 0.05472636815920398
# Lift: 2.0510204081632653
# ...
# Rule: 明顯 → 用
# Support: 0.07462686567164178
# Lift: 2.0510204081632653
# ...
# Rule: 買 → 每個
# Support: 0.05970149253731343
# Lift: 2.0303030303030303
# ...
# Rule: 沒 → 第一
# Support: 0.05970149253731343
# Lift: 2.0303030303030303
# ...
# Rule: 用 → 香味
# Support: 0.06965174129353234
# Lift: 2.0510204081632653
# ...
# Rule: 買 → 男友
# Support: 0.05472636815920398
# ...

# %%
print(dt[200])
# Out:
# ['從', '多月', '前', '修眉時', '不', '小心', '把', '眉頭', '剃', '掉', '😢', '從此', '之', '後', '只要', '有', '出門', '就', '一定', '會畫', '眉毛', '我什麼', '底', '都', '就', '用眉', '筆畫', '可是', '大約', '兩個', '禮拜前', '我現', '在', '只要', '每畫', '一次', '眉毛', '一邊', '都', '會', '掉', '一到', '根毛', '😨', '😨', '😨', '不行', '了', '下去', '的', '眉毛', '要', '沒', '了', '爬', '了', '文', '關於', '這', '方面', '的', '資訊', '只有', '一兩篇', '😭', '我用', '的', '眉筆', '是', 'innisfree', '和', '媚點', '兩', '支眉筆', '做', '混色', '卸妝', '是', '用', '1028', '的', '眼唇', '卸妝液', '告訴', '為', '會', '嗎', '拜', '託', '救救', '的', '眉毛', '🙏', '🙏', '🙏', '之', '後', '打底', '畫會', '比', '較', '好', '嗎', '們', '的', '回答', '(', 'T', '_', 'T', ')']

# %%
# s1 = ('MAC', 'M.A.C','Lancome','蘭蔻','LANEIGE','蘭芝','CHANEL', '香奈兒','雅詩','Estee Lauder','Maybelline', '媚比琳','ARMANI' , 'GA','SHISEIDO', '資生堂','Loreal', '巴黎萊雅','Laura mercier','蘿拉蜜思','innisfree','YSL','NARS','DIOR','植村秀','Cle De Peau','肌膚之鑰','Kose','高絲','kate','媚點','Etude house','Missha','Kissme','Pony Effect','1028','integrate''Orbis','MUF','Make up for ever','Make up forever','Sofina','NYX','Bobbi Brown','IM MEME','solone','3ce','APIEU','The saem','romand','UNNY')
# s2 = ('粉底液','粉餅','粉霜','氣墊','遮瑕膏','遮瑕盤','妝前乳','修容','腮紅','頰彩','蜜粉','蜜粉餅','定妝噴霧','眼影','睫毛膏','眼線液','眼線膠','眼線筆','美妝蛋','粉底刷','腮紅刷','眼影刷','蜜粉刷','唇刷','遮瑕刷','修容刷','睫毛夾','化妝海綿','唇膏','唇彩','唇釉','口紅','唇蜜','潤唇膏', '唇粹', '唇露','眉筆','眉粉','眉膏','眉蠟','眉膠','眼影','睫毛膏','眼線液','眼線膠','眼線筆','定妝噴霧')
