# %% [markdown]
# 根據把首頁往下滑，發現網站會對server送一個GET請求下一個30篇文章
# - 2018(G) https://ithelp.ithome.com.tw/articles/10203216
# - 2019(G) https://tlyu0419.github.io/2019/04/06/Crawl-Dcard/
# - 2020 https://blog.jiatool.com/posts/dcard_api_v2/

# %% [markdown]
# ### API root
#
# - 看板資訊 http://dcard.tw/_api/forums
# - 文章資訊 http://dcard.tw/_api/forums/{看板名稱}/posts
# - 文章內文	http://dcard.tw/_api/posts/{文章編號}
# - 文章內引用連結	http://dcard.tw/_api/posts/{文章編號}/links
# - 文章內留言	http://dcard.tw/_api/posts/{文章編號}/comments
#
# ### API wirte
# - 文章數量 https://www.dcard.tw/_api/posts?limit=100
# - 文章分頁 http://dcard.tw/_api/posts/?before=文章id (before 回傳由新到舊 after舊到新)
# - 文章留言 http://dcard.tw/_api/posts/文章id/comments
# - 留言分頁 http://dcard.tw/_api/posts/文章id/comments?after=floor數字
# - 熱門文章 https://dcard.tw/_api/posts?popular=true
#
# ### others
# 文章資訊(meta) 與 文章內留言 預設使用熱門度 (popularity) 作為排序，而且一次請求 (request) 中只回應 30 筆。
# * 想要讓這兩項使用 時間 排序，可在 GET 參數中加入 popular=false
# * 欲取得更多的 文章資訊(meta)，可以使用 before={某文章編號}來獲得早於 #{某文章編號} 的另外 30 筆 資訊。
# * 欲取得更多的 文章內留言，可以使用 after={某樓層} 來獲得大於 #{某樓層} 的另外 30 筆 留言。

# %%
import requests
import json
import pandas as pd    # 引用套件並縮寫為 pd
from bs4 import BeautifulSoup
# https://www.dcard.tw/f/makeup

# %% [markdown]
# GET 美妝版首頁，Use BeautifulSoup with html, wrtie a txt

# %%
p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/f/makeup")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
#sel

#for link in sel:
#    a.append(link["href"])
    #print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def Catch(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# KeyError: 'id'
# Oh！文章不見了 這篇文章已被作者刪除。 按這裡 看更多文章吧
# https://www.dcard.tw/f/makeup/p/235079399
# Catch(235079399)

# %%
# # 1w : 234227720
# # 2w : 233254532
# # 3w : 232166760
# # 4w : 231148015
# # 5w : 230149776
# url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=233254532"

# %%
import random
import time

#url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=231148015" 
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True) 
#df
print(str(int(df['id'].tail(1))) )
# Out:
# 231148004

# %%
count = 0
delay_choices = [3, 5, 7]  # delay second
delay = random.choice(delay_choices) 

for j in range(1):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    delay = random.choice(delay_choices)
    time.sleep(delay)  
df.to_csv('data/Dcard_makeup.csv', index=False,encoding = "UTF-8")
print(df.shape)
df
# Out:
# 231137891
# data reading... 1 id: 231137769 #分享 #阿皂屋體驗包
# data reading... 2 id: 231137592 ＃圖 GA官網買黑絲絨粉餅霜＋唇膏快速到貨分享
# data reading... 3 id: 231137536 李聖經代言隱眼CC（愛爾康）
# data reading... 4 id: 231137535 Clart'e spa 珂萊緹
# data reading... 5 id: 231137520 首次購入倩碧📌保濕平衡修護組
# data reading... 6 id: 231137429 新手眉毛求批🙏🏻🙏🏻🙏🏻
# data reading... 7 id: 231137282 有人知道這個品牌嗎
# data reading... 8 id: 231137216 #文長 30天粉底挑戰💪 Part3
# data reading... 9 id: 231137097 26樣長痘痘時會想買的保養品大補帖🌞🌿
# data reading... 10 id: 231136854 Yes Please！日常眼妝分享
# data reading... 11 id: 231136797 有沒有人買過solid state 香膏
# data reading... 12 id: 231136794 #情報 買integrate彩妝組合抽Dyson造型器
# data reading... 13 id: 231136777 🇰🇷亂亂買
# data reading... 14 id: 231136643 關於洗臉時機
# data reading... 15 id: 231136621 姊姊看到新東西 就買😂😂
# data reading... 16 id: 231136574 台中霧眉#問
# data reading... 17 id: 231136560 會因為唇彩的關係換深1號粉底嗎？
# data reading... 18 id: 231136534 契爾氏Kiehl’s 唇部護理系列（護唇膏/美唇油） 💄不專業心得比較！
# data reading... 19 id: 231136468 #粉紅控 美到冒泡的保養品們 (后/GA)
# data reading... 20 id: 231136298 #有人買過shein的刷具嗎😂
# data reading... 21 id: 231136278 有人也突然長很多小黑痣嗎？
# data reading... 22 id: 231136272 essence 楓采頰彩盤畫眼妝
# data reading... 23 id: 231136043 新莊超美光療分享 ❤️ #美甲
# data reading... 24 id: 231135888 開價腮紅
# data reading... 25 id: 231135831 推坑#帝康艾綺拉Akira日拋
# data reading... 26 id: 231135829 Colourpop she 玫瑰盤眼妝分享🌹
# data reading... 27 id: 231135806 #分享色號 植村秀無極限超時輕粉底液 #574 #564 #674 #664
# data reading... 28 id: 231135784 #實測 KATE零瑕肌密粉底液
# data reading... 29 id: 231135522 GEO隱眼分享《eyenig glam brown》
# data reading... 30 id: 231135456 春夏秋冬回不去的光療美甲分享❤️
# data reading... 31 id: 231135354 #問 美白乳液
# data reading... 32 id: 231135282 內有與yes please簡單比對🍁essence限定自然楓采頰彩盤🍁
# data reading... 33 id: 231135202 solone 單顆眼影跟excel sr06試色
# data reading... 34 id: 231135123 Etude house修容
# data reading... 35 id: 231135081 昨日板橋大遠百迪奧澎派的靠櫃分享💋
# data reading... 36 id: 231135079 #分享 三色不同風格的MAC Powder Kiss絲柔粉霧唇膏
# data reading... 37 id: 231135054 📍新手入內，輕鬆理解為什麼會有黑頭？粉刺？
# data reading... 38 id: 231134912 #問卷 IG美妝廣告調查
# data reading... 39 id: 231134882 2019年第一季空空賞(文長)
# data reading... 40 id: 231134874 #Mac 316 devoted to chili #Loreal 233 氣質玫瑰 試問兩色差異
# data reading... 41 id: 231134857 台南美甲分享💅
# data reading... 42 id: 231134856 #情報 植村秀潔顏油買150ml送150ml！
# data reading... 43 id: 231134848 粉底條疑問
# data reading... 44 id: 231134840 #試色分享 全開架8隻唇彩分享
# data reading... 45 id: 231134832 Venus marble《拜金主義》試色眼妝分享👀
# data reading... 46 id: 231134828 台中隆鼻 有人知道這是哪一家嗎？還有推薦的自然隆鼻嗎？
# data reading... 47 id: 231134777 #分享 heme唇膏
# data reading... 48 id: 231134588 #分享 #台中美甲 每次都充滿驚喜的指甲
# data reading... 49 id: 231134460 #圖多 #文長 我是抽獎狂！！！part.3
# data reading... 50 id: 231134391 發現隱眼盒子有奇怪東西
# data reading... 51 id: 231134349 平價腮紅&打亮分享😊
# data reading... 52 id: 231134130 第一次看閃光用這麼貴婦的保養！🤷‍♀️
# data reading... 53 id: 231134013 請益）想入手 tripollar stop 童顏機
# data reading... 54 id: 231133854 那道光真的很自然的美＃MUFE  Soft light
# data reading... 55 id: 231133838 #情報 solone單色眼影包裝升級
# data reading... 56 id: 231133764 夏天香水
# data reading... 57 id: 231133732 想問下大家第一次買專櫃粉底液的經驗
# data reading... 58 id: 231133658 大創眉筆重出江湖
# data reading... 59 id: 231133657 不知道有沒有人腿毛跟我一樣粗的
# data reading... 60 id: 231133405 美木希冰沙灰試戴（網路限定）
# data reading... 61 id: 231133329 Innisfree 的市場問卷調查/針對保養品
# data reading... 62 id: 231133246 #不專業分享Giorgio armani 底妝類🌸
# data reading... 63 id: 231133232 期中考前被指甲美到讀不下去
# data reading... 64 id: 231133185 祕之海 海鹽油好不好用
# data reading... 65 id: 231132612 #圖  美甲分享
# data reading... 66 id: 231132072 不專業11支💃🏼開架✨口紅💄唇釉#手部#試色分享🌺
# data reading... 67 id: 231131879 母親節禮物 選手選擇🙏🏼🙇‍♀️
# data reading... 68 id: 231131838 #問 Dior眼影
# data reading... 69 id: 231131624 #問 有沒有人買了唇膏卻到現在還沒用過？
# data reading... 70 id: 231131434 痘疤皮膚拯救紀錄！（非業配）
# data reading... 71 id: 231131401 solone戀色迷棕眼影盤#2試色
# data reading... 72 id: 231131271 母親節禮物
# data reading... 73 id: 231131239 #隱眼 part1 20款一年份日拋戴給你看
# data reading... 74 id: 231131192 按摩哪裡能塑型啊？
# data reading... 75 id: 231131170 #問 讓我又愛又恨的雪芙蘭潤色護唇膏
# data reading... 76 id: 231131161 Mac 314&923 手臂簡單試色🍑
# data reading... 77 id: 231131135 #唇膏 MAC熱門色疊擦
# data reading... 78 id: 231131068 近期購物💸 EXCEL 蜜粉 黑金條唇膏💄
# data reading... 79 id: 231131058 求痘痘藥哪裡有賣
# data reading... 80 id: 231131011 #問 有沒有也是嘴唇兩個色的
# data reading... 81 id: 231130986 這樣就沒了嗎😢😢😢
# data reading... 82 id: 231130954 氣質裸白，是近期的愛～
# data reading... 83 id: 231130859 波蘭品牌Ziaja
# data reading... 84 id: 231130723 #試色 泰國平價彩妝4U2 love me harder霧面唇釉04心得分享
# data reading... 85 id: 231130688 我的最愛粉餅PK！
# data reading... 86 id: 231130565 不專業FIT ME分享（嫩粉餅.粉底液.蜜粉餅
# data reading... 87 id: 231130538 #圖 水晶指甲矯正
# data reading... 88 id: 231130524 沒蛋黃的蛋蛋
# data reading... 89 id: 231130510 請問這是什麼牌子？
# data reading... 90 id: 231130471 #分享 #剛剛好的粉盒
# data reading... 91 id: 231130459 指甲油買二送二，湊運費
# data reading... 92 id: 231130403 CANMAKE三款腮紅試色
# data reading... 93 id: 231130192 #問 愛斯德瑪 珍珠美肌嫩白乳
# data reading... 94 id: 231130040 💚超美超混血olens Spanish隱眼💚
# data reading... 95 id: 231129994 #碧兒泉水光草精華～2+1用法分享🙋🏻
# data reading... 96 id: 231129976 （實戴圖）cocoview自然灰色隱眼👀
# data reading... 97 id: 231129871 #innisfree 沒有最狂 只有更狂 送很大!!!!!🤣🤣🤣🤣🤣
# data reading... 98 id: 231129669 #圖 ELLE路跑完賽禮分享 #優若美折扣碼 #初時肌
# data reading... 99 id: 231129651 發問:屈臣氏特定會員85折折扣怪怪的
# data reading... 100 id: 231129624 皮秒價錢(ﾉ´ ᐛ )ﾉ*:･ﾟ？？
# (201, 10)
#             id                               title  \
# 0    231148004                       #請益 無酒精的美白保養品
# 1    231147886                      #閒聊 你心目中的刷具之王？
# 2    231147742                                  霧眉
# 3    231147734                           #問 防曬需要卸嗎
# 4    231147726                           雙眼皮膠水好有用！
# ..         ...                                 ...
# 196  231129976                （實戴圖）cocoview自然灰色隱眼👀
# 197  231129871  #innisfree 沒有最狂 只有更狂 送很大!!!!!🤣🤣🤣🤣🤣
# 198  231129669         #圖 ELLE路跑完賽禮分享 #優若美折扣碼 #初時肌
# 199  231129651                  發問:屈臣氏特定會員85折折扣怪怪的
# 200  231129624                  皮秒價錢(ﾉ´ ᐛ )ﾉ*:･ﾟ？？
#
#                                                content  \
# 0    我的膚質是敏感肌，想找無酒精的美白保養品😳\n目前只知道BEVY C.美白是無酒精的\nht...
# 1    昨天收到一批受受狼 開箱用覺得刷毛好蘇福啊！\n但心目中刷具之王還是植村秀的55刷無誤！\n...
# 2    想請問一下在基隆或台北有推薦霧眉的店家嗎？\n想去霧眉但找不到合適的店家\n希望有推薦的店家...
# 3    我買了一瓶無色的防曬乳，上網查發現說要卸不卸的回答都有。\n想請問大家擦無色的純防曬乳會卸嗎...
# 4    一直以來我都大小眼一邊內雙一邊外雙，\n\nhttp://i.imgur.com/NNdZJ...
# ..                                                 ...
# 196  大家晚安 第一次就在美妝版發文！！！\n\n原本一直都是戴透明片\n但是頭髮剪短之後風格變成...
# 197  —————更新可忽略 請下滑——————-\n歐抹歐抹，上熱門了\n真的嚇死寶寶了\n回覆裡...
# 198  這週一直下雨\n原本以為週六ELLE的路跑要泡湯了\n還好天氣不錯☀️☀️☀️\n\n順利跑...
# 199  如題\n我抽到了特定會員開架彩妝85折的簡訊\nhttps://i.imgur.com/WE...
# 200  有ㄇ有人知道皮秒雷射除痘疤一次大概要多少啊？？\n想要去蓓爾黛做皮秒\n知道range很廣還...
#
#                                                excerpt  \
# 0    我的膚質是敏感肌，想找無酒精的美白保養品，目前只知道BEVY C.美白是無酒精的，上次看到有...
# 1    昨天收到一批受受狼 開箱用覺得刷毛好蘇福啊！，但心目中刷具之王還是植村秀的55刷無誤！，這把...
# 2    想請問一下在基隆或台北有推薦霧眉的店家嗎？想去霧眉但找不到合適的店家，希望有推薦的店家能與我...
# 3    我買了一瓶無色的防曬乳，上網查發現說要卸不卸的回答都有。想請問大家擦無色的純防曬乳會卸嗎？還...
# 4    一直以來我都大小眼一邊內雙一邊外雙，某天照鏡子突然覺得欸  好像真的差滿多的，就隨便去寶雅買...
# ..                                                 ...
# 196  大家晚安 第一次就在美妝版發文！！！，原本一直都是戴透明片，但是頭髮剪短之後風格變成可愛風，...
# 197  —————更新可忽略 請下滑——————-，歐抹歐抹，上熱門了，真的嚇死寶寶了，回覆裡有水水...
# 198  這週一直下雨，原本以為週六ELLE的路跑要泡湯了，還好天氣不錯️️️，順利跑完後，到攤位排隊...
# 199  如題，我抽到了特定會員開架彩妝85折的簡訊，然後今天就開心的跑去買了，問題來了Integra...
# 200  有ㄇ有人知道皮秒雷射除痘疤一次大概要多少啊？？想要去蓓爾黛做皮秒，知道range很廣還是想抓...
#
#                     createdAt                 updatedAt forumName forumAlias  \
# 0    2019-04-23T06:54:01.936Z  2019-04-23T06:54:01.936Z        美妝     makeup
# 1    2019-04-23T06:34:34.241Z  2019-04-23T06:34:34.241Z        美妝     makeup
# 2    2019-04-23T06:08:52.937Z  2019-04-23T06:08:52.937Z        美妝     makeup
# 3    2019-04-23T06:06:20.488Z  2019-04-23T06:06:20.488Z        美妝     makeup
# 4    2019-04-23T06:05:07.541Z  2019-04-23T06:06:08.209Z        美妝     makeup
# ..                        ...                       ...       ...        ...
# 196  2019-04-20T13:49:29.591Z  2019-04-20T13:51:55.694Z        美妝     makeup
# 197  2019-04-20T13:32:34.855Z  2019-04-21T14:44:37.841Z        美妝     makeup
# 198  2019-04-20T12:59:06.510Z  2019-04-20T12:59:06.510Z        美妝     makeup
# 199  2019-04-20T12:55:41.777Z  2019-04-20T12:55:41.777Z        美妝     makeup
# 200  2019-04-20T12:52:49.994Z  2019-04-20T12:52:49.994Z        美妝     makeup
#
#     gender  topics
# 0        F      NaN
# 1        F      NaN
# 2        F      NaN
# 3        F      NaN
# 4        F      NaN
# ..     ...      ...
# 196      F      NaN
# 197      F      NaN
# 198      F      NaN
# 199      F      NaN
# 200      F      NaN
#
# [201 rows x 10 columns]

# %% [markdown]
# # ---------------正式版本分隔線---------------
# - 測試版本代號：1.2  2020
# - 正式版本代號：2.03  2021
# - 開發人員： EGG Jerry Three

# %% [markdown]
# dva.x_x 版本開發

# %%
#找到 dav.x_x 發表過的文章

p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/@dva.x_x")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
sel
a=[]
for link in sel:
    a.append(link["href"])
    print(link.get('href')[-9:])
    print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def CatchUser(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'department':rejs['department'],  #for author
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'department':"",    #for author
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# 熱門美妝版測試 (100筆)
url = 'https://www.dcard.tw/@dva.x_x'
#url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=5'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(CatchUser(rejs[i]['id']),ignore_index=True)   #0 - 29
print(df.shape)
#df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(CatchUser(rejs[0]['id']),ignore_index=True) 
#df
print(str(int(df['id'].tail(1))) )

count = 0
delay_choices = [1, 3, 5]  # delay second
delay = random.choice(delay_choices) 

for j in range(1):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    delay = random.choice(delay_choices)
    time.sleep(delay)  
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# slope the title
def CatchPost(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
#CatchPost(234999065)
#url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
url = 'https://www.dcard.tw/_api/posts/235103419'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
url = 'https://www.dcard.tw/_api/posts/234912821'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
# url = 'https://www.dcard.tw/_api/posts/235103302'
resq = requests.get(url)
rejs = resq.json()
rejs

# %% [markdown]
# # --------------- dva.x_x 版本分隔線 ---------------
# - 測試版本代號：Jerry 1.0
# - 開發人員： Jerry

# %%
#test = open("data/test.txt","w",encoding='UTF-8')

# %%
# asb
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=99"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True)   #0 - 29

delay_choices = [1]#, 3, 5, 7,20]  #延遲的秒數
delay = random.choice(delay_choices)  #隨機選取秒數

for j in range(10):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=true&limit=99&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 101 == 0:
            print('第',j,'次執行，data reading...',i,'last',last,'chocice',delay)
    delay = random.choice(delay_choices)  #隨機選取秒數
    time.sleep(delay)  #延遲

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# 熱門美妝版測試 (100筆)
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']),ignore_index=True)   #0 - 29
    if i % 20 == 0:
        print('data reading...',i)
print(df.shape)
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
#last = str(int(df['ID'].tail(1))) #last dt
#last

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df['ID'].tail(1))) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&before=' + last
    #url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 10 == 0:
            print('第',j,'次執行，data reading...',i)
            
print(df.shape)
df

# %%
last = str(int(df['ID'].tail(1)))
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df

# %%
# 熱門美妝版測試 (100筆)

for i in range(10):
    last = str(int(df['ID'].tail(1)))
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    df = pd.DataFrame()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']),ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
    print(df.shape)

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df

# 99	235031315	#請益 #問 LA girl 遮瑕挑色

# %%
last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID '235031315'
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)


df

# %%
#df

# %%
##ok ^
for j in range(3):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)
#df

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
print(df.shape)
df

# %%
df.to_excel('data/Dcard_markeup.excel', index=False)

# %% [markdown]
# 欄位	說明	備註
# ID	編號
# title	標題
# content	內容
# excerpt	摘要
# createdAt	發布時間
# updatedAt	更新時間
# commentCount	留言數
# forumName	分類	中文
# forumAlias	分類	英文
# gender	性別
# likeCount	心情數量
# reactions	心情細項	把以上心情細分為「愛心」、「哈哈」、「跪」、「森77」、「驚訝」等類型
# topics	標籤

# %%
# 固定碼測試
def Catch_test(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )
Catch_test(235020702)
