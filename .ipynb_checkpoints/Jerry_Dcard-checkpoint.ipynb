# %%
import requests
import json
import pandas as pd    # 引用套件並縮寫為 pd
from bs4 import BeautifulSoup
# https://www.dcard.tw/f/makeup

# %% [markdown]
# GET 美妝版首頁，Use BeautifulSoup with html, wrtie a txt

# %%
test = open("data/test.txt","w",encoding='UTF-8')

p = requests.Session()                            # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/f/makeup") # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
a=[]
for link in sel:
    a.append(link["href"])
    print('https://www.dcard.tw'+link.get('href'))
# Out:
# https://www.dcard.tw/f/makeup/p/235022153
# https://www.dcard.tw/f/makeup/p/235025010
# https://www.dcard.tw/f/makeup/p/235026845
# https://www.dcard.tw/f/makeup/p/235025318
# https://www.dcard.tw/f/makeup/p/235029187
# https://www.dcard.tw/f/makeup/p/235028318
# https://www.dcard.tw/f/makeup/p/235026239
# https://www.dcard.tw/f/makeup/p/235025794
# https://www.dcard.tw/f/makeup/p/235031893
# https://www.dcard.tw/f/makeup/p/235025582
# https://www.dcard.tw/f/makeup/p/235029094
# https://www.dcard.tw/f/makeup/p/235027858
# https://www.dcard.tw/f/makeup/p/235025935
# https://www.dcard.tw/f/makeup/p/235029490
# https://www.dcard.tw/f/makeup/p/235032541
# https://www.dcard.tw/f/makeup/p/235024986
# https://www.dcard.tw/f/makeup/p/235031258
# https://www.dcard.tw/f/makeup/p/235029001
# https://www.dcard.tw/f/makeup/p/235025212
# https://www.dcard.tw/f/makeup/p/235029009
# https://www.dcard.tw/f/makeup/p/235028888
# https://www.dcard.tw/f/makeup/p/235027700
# https://www.dcard.tw/f/makeup/p/235031953
# https://www.dcard.tw/f/makeup/p/235028700
# https://www.dcard.tw/f/makeup/p/235032156
# https://www.dcard.tw/f/makeup/p/235030587
# https://www.dcard.tw/f/makeup/p/235028686
# https://www.dcard.tw/f/makeup/p/235029307
# https://www.dcard.tw/f/makeup/p/235029706
# https://www.dcard.tw/f/makeup/p/235031590

# %%
#a
url = "https://www.dcard.tw"+ a[1]
url
# Out:
# 'https://www.dcard.tw/f/makeup/p/235021477'

# %% [markdown]
# 根據把首頁往下滑，發現網站會對server送一個GET請求下一個30篇文章
# - 2018(G) https://ithelp.ithome.com.tw/articles/10203216
# - 2019(G) https://tlyu0419.github.io/2019/04/06/Crawl-Dcard/
# - 2020 https://blog.jiatool.com/posts/dcard_api_v2/

# %% [markdown]
# ### API root
#
# - 看板資訊 http://dcard.tw/_api/forums
# - 文章資訊 http://dcard.tw/_api/forums/{看板名稱}/posts
# - 文章內文	http://dcard.tw/_api/posts/{文章編號}
# - 文章內引用連結	http://dcard.tw/_api/posts/{文章編號}/links
# - 文章內留言	http://dcard.tw/_api/posts/{文章編號}/comments
#
# ### API wirte
# - 文章數量 https://www.dcard.tw/_api/posts?limit=100
# - 文章分頁 http://dcard.tw/_api/posts/?before=文章id (before 回傳由新到舊 after舊到新)
# - 文章留言 http://dcard.tw/_api/posts/文章id/comments
# - 留言分頁 http://dcard.tw/_api/posts/文章id/comments?after=floor數字
# - 熱門文章 https://dcard.tw/_api/posts?popular=true
#
# ### others
# 文章資訊(meta) 與 文章內留言 預設使用熱門度 (popularity) 作為排序，而且一次請求 (request) 中只回應 30 筆。
# * 想要讓這兩項使用 時間 排序，可在 GET 參數中加入 popular=false
# * 欲取得更多的 文章資訊(meta)，可以使用 before={某文章編號}來獲得早於 #{某文章編號} 的另外 30 筆 資訊。
# * 欲取得更多的 文章內留言，可以使用 after={某樓層} 來獲得大於 #{某樓層} 的另外 30 筆 留言。

# %%
# 固定碼測試
def Catch_test(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )
Catch_test(235020702)
# Out:
#           ID         title                                            content  \
# 0  235020702  發現冬天好適合用粉霜喔!  入冬後我臉已開始乾TT\n之前夏天用MUF粉餅 遮瑕力跟控油力都不錯\n但冬天用真的不夠保濕...
#
#                                              excerpt  \
# 0  入冬後我臉已開始乾TT，之前夏天用MUF粉餅 遮瑕力跟控油力都不錯，但冬天用真的不夠保濕，最...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2020-12-21T02:26:52.040Z  2020-12-21T02:34:47.300Z        美妝     makeup
#
#   gender  topics
# 0      F      NaN

# %%
url = 'https://www.dcard.tw/_api/posts/235020702'  #測試1
#url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true'  #測試2
requ = requests.get(url)
rejs = requ.json()
rejs
# Out:
# {'id': 235020702,
#  'title': '發現冬天好適合用粉霜喔!',
#  'content': '入冬後我臉已開始乾TT\n之前夏天用MUF粉餅 遮瑕力跟控油力都不錯\n但冬天用真的不夠保濕\n最近發現了有粉霜這種材質 之前只知道粉底液很保濕 \n但粉底液我常常沒用完就過期了XD\n就納入了新的粉霜~covermark的水鑽石\nhttps://i.imgur.com/o2D1n1A.jpg\n單看上去會覺得很像膏類製質地\n但抹開來就化掉了 輕拍在臉上保濕力超好\n以前我眼下遮瑕都會另外遮\n但這個直接可以把我黑眼圈遮掉 很不錯用\n分享我今年的冬天蜜糖給大家><',
#  'excerpt': '入冬後我臉已開始乾TT，之前夏天用MUF粉餅 遮瑕力跟控油力都不錯，但冬天用真的不夠保濕，最近發現了有粉霜這種材質 之前只知道粉底液很保濕，但粉底液我常常沒用完就過期了XD，就納入了新的粉霜~cove',
#  'anonymousSchool': False,
#  'anonymousDepartment': True,
#  'pinned': False,
#  'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#  'replyId': None,
#  'createdAt': '2020-12-21T02:26:52.040Z',
#  'updatedAt': '2020-12-21T02:34:47.300Z',
#  'commentCount': 28,
#  'likeCount': 660,
#  'tags': [],
#  'topics': ['粉霜'],
#  'supportedReactions': None,
#  'withNickname': False,
#  'reportReason': '',
#  'hiddenByAuthor': False,
#  'meta': {'layout': 'classic'},
#  'forumName': '美妝',
#  'forumAlias': 'makeup',
#  'nsfw': False,
#  'school': '文藻外語大學',
#  'replyTitle': None,
#  'gender': 'F',
#  'personaSubscriptable': True,
#  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 659},
#   {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#  'hidden': False,
#  'customStyle': None,
#  'isSuspiciousAccount': False,
#  'isModerator': False,
#  'layout': 'classic',
#  'spoilerAlert': False,
#  'withImages': True,
#  'withVideos': False,
#  'media': [{'url': 'https://i.imgur.com/o2D1n1A.jpg'}],
#  'reportReasonText': '',
#  'mediaMeta': [{'id': '898b9f3a-dd8e-42bb-b047-fb2b8e74ce03',
#    'url': 'https://i.imgur.com/o2D1n1Al.jpg',
#    'normalizedUrl': 'https://i.imgur.com/o2D1n1Al.jpg',
#    'thumbnail': 'https://i.imgur.com/o2D1n1Al.jpg',
#    'type': 'image/thumbnail',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-12-21T02:34:47.300Z',
#    'updatedAt': '2020-12-21T02:34:47.300Z',
#    'width': 1108,
#    'height': 1478},
#   {'id': '898b9f3a-dd8e-42bb-b047-fb2b8e74ce03',
#    'url': 'https://i.imgur.com/o2D1n1A.jpg',
#    'normalizedUrl': 'https://imgur.com/o2D1n1A',
#    'thumbnail': 'https://i.imgur.com/o2D1n1Al.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-12-21T02:34:47.300Z',
#    'updatedAt': '2020-12-21T02:34:47.300Z',
#    'width': 1108,
#    'height': 1478}],
#  'excerptComments': [],
#  'postAvatar': '',
#  'verifiedBadge': False}

# %%
# slope the title
def Catch(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )

# %%
# 熱門美妝版測試 (100筆)
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']),ignore_index=True)
    if i % 20 == 0:
        print('data reading...',i)
print(df.shape)
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# Out:
# data reading... 0
# data reading... 20
# data reading... 40
# data reading... 60
# data reading... 80
# (88, 10)
#            ID                                 title  \
# 0   235022153  ❄️聖誕妝容推薦❄️ 準備漂亮過節讓你 bling bling 惹人愛！
# 1   235025010               #吐槽大會 那些我2021絕對不會購入的東西🌚
# 2   235026845                         毛孔人必備的幾樣小可愛們✍
# 3   235025318                            舊款焦糖拿鐵的替代品
# 4   235029187                 #分享 約會必備桃花眼妝💐-完美日記錦鯉盤
# ..        ...                                   ...
# 83  235033752                          上完睫毛膏後總是會過敏⋯
# 84  235033698                         #請益 雅詩蘭黛 唇膏問題
# 85  235025113                       #請益 Elemis 這個牌子
# 86  235033798            #請益 Pony effect 水透光妝前防護乳包裝
# 87  235033362                         #有圖 耳骨發炎 蟹足腫？
#
#                                               content  \
# 0   這週就是🎄聖誕節惹⛄️\n各位卡友們餐廳跟交換禮物都準備好了！\n現在應該是萬事俱備 只欠東...
# 1   Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下 \n所以...
# 2   身為毛孔人，只要能讓毛孔縮小一咪咪\n都是讓人值得開心的事情阿～😙\n自己除了有固定使用針對...
# 3   在康是美快打烊的時候 衝了一波他們的99元唇膏\n也不想造成店員困擾 於是也沒試色拿了一隻顏...
# 4   哈囉大家好這裡是最近很高產的兔子🐰\n之後可能就不會這麼常發文了\n想趕快把手邊能分享的產品...
# ..                                                ...
# 83  如題\n上次上完睫毛膏晚點後幾乎都會紅腫\n忍不住去揉眼睛\n然後就糊掉⋯\n\n就算卸妝完...
# 84  由於要送人可是比較不了解\n\n想請問絕對慾望奢華潤唇膏 有在官網看到420有3.5g的\n...
# 85  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
# 86  之前在MEMEBOX買過妝前防護乳，用完後找了蝦皮代購再次購入。打開發現包裝和MEMEBOX...
# 87  最近手癢癢亂摳耳骨的環=...=\n導致他又發炎了⋯\n給圖幫我看看會變成蟹足腫嗎😭😭😭\n...
#
#                                               excerpt  \
# 0   這週就是聖誕節惹️，各位卡友們餐廳跟交換禮物都準備好了！，現在應該是萬事俱備 只欠東風，是聖...
# 1   Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下，所以今天...
# 2   身為毛孔人，只要能讓毛孔縮小一咪咪，都是讓人值得開心的事情阿～自己除了有固定使用針對毛孔的保...
# 3   在康是美快打烊的時候 衝了一波他們的99元唇膏，也不想造成店員困擾 於是也沒試色拿了一隻顏色...
# 4   哈囉大家好這裡是最近很高產的兔子，之後可能就不會這麼常發文了，想趕快把手邊能分享的產品分享出...
# ..                                                ...
# 83  如題，上次上完睫毛膏晚點後幾乎都會紅腫，忍不住去揉眼睛，然後就糊掉⋯，就算卸妝完 那幾天眼皮...
# 84  由於要送人可是比較不了解，想請問絕對慾望奢華潤唇膏 有在官網看到420有3.5g的，而pch...
# 85  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
# 86  之前在MEMEBOX買過妝前防護乳，用完後找了蝦皮代購再次購入。打開發現包裝和MEMEBOX...
# 87  最近手癢癢亂摳耳骨的環=...=，導致他又發炎了⋯，給圖幫我看看會變成蟹足腫嗎，還是只是單純...
#
#                    createdAt                 updatedAt forumName forumAlias  \
# 0   2020-12-21T07:07:47.084Z  2020-12-21T10:13:21.728Z        美妝     makeup
# 1   2020-12-21T14:45:24.926Z  2020-12-21T14:45:24.926Z        美妝     makeup
# 2   2020-12-22T00:38:00.446Z  2020-12-22T00:38:00.446Z        美妝     makeup
# 3   2020-12-21T15:29:36.622Z  2020-12-21T15:29:36.622Z        美妝     makeup
# 4   2020-12-22T08:35:30.926Z  2020-12-22T08:36:44.262Z        美妝     makeup
# ..                       ...                       ...       ...        ...
# 83  2020-12-23T01:56:52.572Z  2020-12-23T01:58:12.037Z        美妝     makeup
# 84  2020-12-23T01:44:00.670Z  2020-12-23T01:44:00.670Z        美妝     makeup
# 85  2020-12-21T14:59:34.846Z  2020-12-21T15:01:12.933Z        美妝     makeup
# 86  2020-12-23T02:10:31.738Z  2020-12-23T02:10:31.738Z        美妝     makeup
# 87  2020-12-22T22:57:18.287Z  2020-12-22T22:57:18.287Z        美妝     makeup
#
#    gender  topics
# 0       D      NaN
# 1       F      NaN
# 2       F      NaN
# 3       F      NaN
# 4       F      NaN
# ..    ...      ...
# 83      F      NaN
# 84      M      NaN
# 85      F      NaN
# 86      F      NaN
# 87      F      NaN
#
# [88 rows x 10 columns]

# %% [markdown]
# # ---------------正式版本分隔線---------------
# - 測試版本代號：EGG_1.2
# - 開發人員： EGG Jerry Three

# %%
last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID '235031315'
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)


df
# Out:
# (107, 10)
#             ID                                 title  \
# 0    235022153  ❄️聖誕妝容推薦❄️ 準備漂亮過節讓你 bling bling 惹人愛！
# 1    235021477                  🔥#圖多#試色 MAC唇膏眼影底妝失心瘋
# 2    235025010               #吐槽大會 那些我2021絕對不會購入的東西🌚
# 3    235022346               #分享 日常上學眼妝٩(˃̶͈̀௰˂̶͈́)و
# 4    235021551                 #分享 來一朵煙灰玫瑰，HERA #499
# ..         ...                                   ...
# 102  235031158                       #分享 YSL香港官網送貨時間
# 103  235029572                          #討論 小棕瓶瓶身掉亮粉
# 104  235032156                 終於脫單😚 聖誕節跟男友過夜的決戰保養小包
# 105  235025629                          霓淨思 玻尿酸深度潤澤霜
# 106  235025113                       #請益 Elemis 這個牌子
#
#                                                content  \
# 0    這週就是🎄聖誕節惹⛄️\n各位卡友們餐廳跟交換禮物都準備好了！\n現在應該是萬事俱備 只欠東...
# 1    哈摟大家好!🙋🏻\n今天是我隔離的最後一天了\n來檢討的是我黑五沒忍住爆買了MAC😂\n經典...
# 2    Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下 \n所以...
# 3    大家午安\n今天想跟大家分享三個日常上學眼妝\n\n第一跟第二個都是用NYX的warm ne...
# 4    嗨嗨大家好～～\n先來一張人間香奈兒當鎮樓圖(⁎⁍̴̛ᴗ⁍̴̛⁎)\nhttps://i.i...
# ..                                                 ...
# 102  請問有無sis試過係Ysl香港官方網站落order？通常幾耐收到貨？我星期一（琴日）夜晚落單...
# 103  想請問各位的小棕瓶會有掉亮粉的情況嗎？\nhttps://i.imgur.com/0Nem6...
# 104  今年總算在聖誕節前脫單了(轉圈灑花🌸🌸)\n跟男友約好要去住他家然後一起去耶誕城拍拍照\n一...
# 105  我在屈臣氏看到這個在特價 就買下去\n但是我塗上去之後 覺得味道不好聞\n是正常ㄉㄇ⋯⋯ 有...
# 106  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
#
#                                                excerpt  \
# 0    這週就是聖誕節惹️，各位卡友們餐廳跟交換禮物都準備好了！，現在應該是萬事俱備 只欠東風，是聖...
# 1    哈摟大家好！，今天是我隔離的最後一天了，來檢討的是我黑五沒忍住爆買了MAC，經典黑管唇膏打6...
# 2    Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下，所以今天...
# 3    大家午安，今天想跟大家分享三個日常上學眼妝，第一跟第二個都是用NYX的warm neutra...
# 4    嗨嗨大家好～～先來一張人間香奈兒當鎮樓圖（⁎⁍̴̛ᴗ⁍̴̛⁎），是滴！今天要分享的是煎妮代言...
# ..                                                 ...
# 102  請問有無sis試過係Ysl香港官方網站落order？通常幾耐收到貨？我星期一（琴日）夜晚落單...
# 103                                想請問各位的小棕瓶會有掉亮粉的情況嗎？
# 104  今年總算在聖誕節前脫單了（轉圈灑花），跟男友約好要去住他家然後一起去耶誕城拍拍照，一邊收行李...
# 105  我在屈臣氏看到這個在特價 就買下去，但是我塗上去之後 覺得味道不好聞，是正常ㄉㄇ⋯⋯ 有人口...
# 106  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
#
#                     createdAt                 updatedAt forumName forumAlias  \
# 0    2020-12-21T07:07:47.084Z  2020-12-21T10:13:21.728Z        美妝     makeup
# 1    2020-12-21T05:05:27.545Z  2020-12-21T06:22:01.027Z        美妝     makeup
# 2    2020-12-21T14:45:24.926Z  2020-12-21T14:45:24.926Z        美妝     makeup
# 3    2020-12-21T07:37:10.545Z  2020-12-21T07:37:10.545Z        美妝     makeup
# 4    2020-12-21T05:16:38.008Z  2020-12-21T05:19:09.051Z        美妝     makeup
# ..                        ...                       ...       ...        ...
# 102  2020-12-22T14:16:22.085Z  2020-12-22T14:16:22.085Z        美妝     makeup
# 103  2020-12-22T09:46:21.880Z  2020-12-22T09:46:21.880Z        美妝     makeup
# 104  2020-12-22T16:20:59.805Z  2020-12-22T16:20:59.805Z        美妝     makeup
# 105  2020-12-21T16:09:47.957Z  2020-12-21T16:09:47.957Z        美妝     makeup
# 106  2020-12-21T14:59:34.846Z  2020-12-21T15:01:12.933Z        美妝     makeup
#
#     gender  topics
# 0        D      NaN
# 1        F      NaN
# 2        F      NaN
# 3        F      NaN
# 4        F      NaN
# ..     ...      ...
# 102      M      NaN
# 103      M      NaN
# 104      F      NaN
# 105      F      NaN
# 106      F      NaN
#
# [107 rows x 10 columns]

# %%
#df
# Out:
# (121, 10)

# %%
##ok ^
for j in range(3):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)
#df
# Out:
# (121, 10)
#             ID                                 title  \
# 0    235022153  ❄️聖誕妝容推薦❄️ 準備漂亮過節讓你 bling bling 惹人愛！
# 1    235021477                  🔥#圖多#試色 MAC唇膏眼影底妝失心瘋
# 2    235025010               #吐槽大會 那些我2021絕對不會購入的東西🌚
# 3    235022346               #分享 日常上學眼妝٩(˃̶͈̀௰˂̶͈́)و
# 4    235021551                 #分享 來一朵煙灰玫瑰，HERA #499
# ..         ...                                   ...
# 116  235031158                       #分享 YSL香港官網送貨時間
# 117  235029572                          #討論 小棕瓶瓶身掉亮粉
# 118  235025629                          霓淨思 玻尿酸深度潤澤霜
# 119  235032156                 終於脫單😚 聖誕節跟男友過夜的決戰保養小包
# 120  235025113                       #請益 Elemis 這個牌子
#
#                                                content  \
# 0    這週就是🎄聖誕節惹⛄️\n各位卡友們餐廳跟交換禮物都準備好了！\n現在應該是萬事俱備 只欠東...
# 1    哈摟大家好!🙋🏻\n今天是我隔離的最後一天了\n來檢討的是我黑五沒忍住爆買了MAC😂\n經典...
# 2    Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下 \n所以...
# 3    大家午安\n今天想跟大家分享三個日常上學眼妝\n\n第一跟第二個都是用NYX的warm ne...
# 4    嗨嗨大家好～～\n先來一張人間香奈兒當鎮樓圖(⁎⁍̴̛ᴗ⁍̴̛⁎)\nhttps://i.i...
# ..                                                 ...
# 116  請問有無sis試過係Ysl香港官方網站落order？通常幾耐收到貨？我星期一（琴日）夜晚落單...
# 117  想請問各位的小棕瓶會有掉亮粉的情況嗎？\nhttps://i.imgur.com/0Nem6...
# 118  我在屈臣氏看到這個在特價 就買下去\n但是我塗上去之後 覺得味道不好聞\n是正常ㄉㄇ⋯⋯ 有...
# 119  今年總算在聖誕節前脫單了(轉圈灑花🌸🌸)\n跟男友約好要去住他家然後一起去耶誕城拍拍照\n一...
# 120  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
#
#                                                excerpt  \
# 0    這週就是聖誕節惹️，各位卡友們餐廳跟交換禮物都準備好了！，現在應該是萬事俱備 只欠東風，是聖...
# 1    哈摟大家好！，今天是我隔離的最後一天了，來檢討的是我黑五沒忍住爆買了MAC，經典黑管唇膏打6...
# 2    Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下，所以今天...
# 3    大家午安，今天想跟大家分享三個日常上學眼妝，第一跟第二個都是用NYX的warm neutra...
# 4    嗨嗨大家好～～先來一張人間香奈兒當鎮樓圖（⁎⁍̴̛ᴗ⁍̴̛⁎），是滴！今天要分享的是煎妮代言...
# ..                                                 ...
# 116  請問有無sis試過係Ysl香港官方網站落order？通常幾耐收到貨？我星期一（琴日）夜晚落單...
# 117                                想請問各位的小棕瓶會有掉亮粉的情況嗎？
# 118  我在屈臣氏看到這個在特價 就買下去，但是我塗上去之後 覺得味道不好聞，是正常ㄉㄇ⋯⋯ 有人口...
# 119  今年總算在聖誕節前脫單了（轉圈灑花），跟男友約好要去住他家然後一起去耶誕城拍拍照，一邊收行李...
# 120  最近收到一瓶elemis的乳霜，一開始還以為是雜牌，一查才發現是歐美滿有名的牌子（我不識貨X...
#
#                     createdAt                 updatedAt forumName forumAlias  \
# 0    2020-12-21T07:07:47.084Z  2020-12-21T10:13:21.728Z        美妝     makeup
# 1    2020-12-21T05:05:27.545Z  2020-12-21T06:22:01.027Z        美妝     makeup
# 2    2020-12-21T14:45:24.926Z  2020-12-21T14:45:24.926Z        美妝     makeup
# 3    2020-12-21T07:37:10.545Z  2020-12-21T07:37:10.545Z        美妝     makeup
# 4    2020-12-21T05:16:38.008Z  2020-12-21T05:19:09.051Z        美妝     makeup
# ..                        ...                       ...       ...        ...
# 116  2020-12-22T14:16:22.085Z  2020-12-22T14:16:22.085Z        美妝     makeup
# 117  2020-12-22T09:46:21.880Z  2020-12-22T09:46:21.880Z        美妝     makeup
# 118  2020-12-21T16:09:47.957Z  2020-12-21T16:09:47.957Z        美妝     makeup
# 119  2020-12-22T16:20:59.805Z  2020-12-22T16:20:59.805Z        美妝     makeup
# 120  2020-12-21T14:59:34.846Z  2020-12-21T15:01:12.933Z        美妝     makeup
#
#     gender  topics
# 0        D      NaN
# 1        F      NaN
# 2        F      NaN
# 3        F      NaN
# 4        F      NaN
# ..     ...      ...
# 116      M      NaN
# 117      M      NaN
# 118      F      NaN
# 119      F      NaN
# 120      F      NaN
#
# [121 rows x 10 columns]

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
print(df.shape)
df

# %%
df.to_excel('data/Dcard_markeup.excel', index=False)

# %% [markdown]
# 欄位	說明	備註
# ID	編號
# title	標題
# content	內容
# excerpt	摘要
# createdAt	發布時間
# updatedAt	更新時間
# commentCount	留言數
# forumName	分類	中文
# forumAlias	分類	英文
# gender	性別
# likeCount	心情數量
# reactions	心情細項	把以上心情細分為「愛心」、「哈哈」、「跪」、「森77」、「驚訝」等類型
# topics	標籤
