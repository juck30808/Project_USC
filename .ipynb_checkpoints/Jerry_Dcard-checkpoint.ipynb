# %% [markdown]
# 根據把首頁往下滑，發現網站會對server送一個GET請求下一個30篇文章
# - 2018(G) https://ithelp.ithome.com.tw/articles/10203216
# - 2019(G) https://tlyu0419.github.io/2019/04/06/Crawl-Dcard/
# - 2020 https://blog.jiatool.com/posts/dcard_api_v2/

# %% [markdown]
# ### API root
#
# - 看板資訊 http://dcard.tw/_api/forums
# - 文章資訊 http://dcard.tw/_api/forums/{看板名稱}/posts
# - 文章內文	http://dcard.tw/_api/posts/{文章編號}
# - 文章內引用連結	http://dcard.tw/_api/posts/{文章編號}/links
# - 文章內留言	http://dcard.tw/_api/posts/{文章編號}/comments
#
# ### API wirte
# - 文章數量 https://www.dcard.tw/_api/posts?limit=100
# - 文章分頁 http://dcard.tw/_api/posts/?before=文章id (before 回傳由新到舊 after舊到新)
# - 文章留言 http://dcard.tw/_api/posts/文章id/comments
# - 留言分頁 http://dcard.tw/_api/posts/文章id/comments?after=floor數字
# - 熱門文章 https://dcard.tw/_api/posts?popular=true
#
# ### others
# 文章資訊(meta) 與 文章內留言 預設使用熱門度 (popularity) 作為排序，而且一次請求 (request) 中只回應 30 筆。
# * 想要讓這兩項使用 時間 排序，可在 GET 參數中加入 popular=false
# * 欲取得更多的 文章資訊(meta)，可以使用 before={某文章編號}來獲得早於 #{某文章編號} 的另外 30 筆 資訊。
# * 欲取得更多的 文章內留言，可以使用 after={某樓層} 來獲得大於 #{某樓層} 的另外 30 筆 留言。

# %%
import requests
import json
import pandas as pd    # 引用套件並縮寫為 pd
from bs4 import BeautifulSoup
# https://www.dcard.tw/f/makeup

# %% [markdown]
# GET 美妝版首頁，Use BeautifulSoup with html, wrtie a txt

# %%
p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/f/makeup")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
#sel

#for link in sel:
#    a.append(link["href"])
    #print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def Catch(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# KeyError: 'id'
# Oh！文章不見了 這篇文章已被作者刪除。 按這裡 看更多文章吧
# https://www.dcard.tw/f/makeup/p/235079399
# Catch(235079399)

# %%
# # 1w : 234227720
# # 2w : 233254532
# # 3w : 232166760
# # 4w : 231148015
# # 5w : 230149776
# url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=233254532"

# %%
import random
import time

#url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=231148015" 
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True) 
#df
print(str(int(df['id'].tail(1))) )
# Out:
# 231148004

# %%
count = 0
delay_choices = [3, 5, 7]  # delay second
delay = random.choice(delay_choices) 

for j in range(1):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    delay = random.choice(delay_choices)
    time.sleep(delay)  
df.to_csv('data/Dcard_makeup_utf8_.csv', index=False,encoding = "UTF-8")
print(df.shape)
df
# Out:
# 231148004
# data reading... 1 id: 231147886 #閒聊 你心目中的刷具之王？
# data reading... 2 id: 231147742 霧眉
# data reading... 3 id: 231147734 #問 防曬需要卸嗎
# data reading... 4 id: 231147726 雙眼皮膠水好有用！
# data reading... 5 id: 231147705 求植村秀 染唇露bg02試色圖
# data reading... 6 id: 231147693 #試色 完美日記九色眼影 白桃+紅酒
# data reading... 7 id: 231147422 潘x拉 美容診所評價
# data reading... 8 id: 231147402 #問 Elf眼影盤
# data reading... 9 id: 231147289 #圖 光療分享 卡通塗鴉光療
# data reading... 10 id: 231147234 #屏東醫美 分享 #除毛 #除斑 #雷射
# data reading... 11 id: 231147143 #套刷分享 受受狼虞美人三代
# data reading... 12 id: 231147100 #母親節 衝一波蘭芝補貨！🔥🔥🔥
# data reading... 13 id: 231147096 #問 loreal 24H無暇完美粉底液選色
# data reading... 14 id: 231146844 #求推 Bath&Body Works
# data reading... 15 id: 231146805 🌸日韓美妝戰利品分享🌸
# data reading... 16 id: 231146765 新手發問🙏🏻
# data reading... 17 id: 231146740 香水誘惑
# data reading... 18 id: 231146612 防曬選手
# data reading... 19 id: 231146327 美容丙級
# data reading... 20 id: 231146234 #問 mac 12H 染唇露
# data reading... 21 id: 231146133 【補上試色和眼妝畫法】Jeffree Star 藍血眼影盤 Blue Blood
# data reading... 22 id: 231145940 聞到被舔的香水味
# data reading... 23 id: 231145303 L’oréal 220試色
# data reading... 24 id: 231145282 江原道粉底包裝問題
# data reading... 25 id: 231145258 OPT小直徑隱眼分享😍
# data reading... 26 id: 231145187 選擇大障礙之唇膏顏色挑選
# data reading... 27 id: 231145162 口紅請益💄Chili vs Devoted to Chili
# data reading... 28 id: 231145159 #請益 油肌粉底液選擇
# data reading... 29 id: 231145003 #分享 #adopt'香水 愛朵香水使用心得(含2019新香)
# data reading... 30 id: 231144894 去韓國看不了演唱會沒關係 可以割雙眼皮
# data reading... 31 id: 231144730 芭蕾舞風指甲
# data reading... 32 id: 231144726 割雙眼皮一週紀錄
# data reading... 33 id: 231144545 口服A酸3個月 心得分享
# data reading... 34 id: 231144403 戀愛魔鏡8支唇膏-論期中考週腦波弱的後果🧐
# data reading... 35 id: 231144108 AHC新出的防曬好像很厲害
# data reading... 36 id: 231144091 ⚠️照過來Mac絲柔粉霧唇膏
# data reading... 37 id: 231143996 ＃分享 永遠不變心的雅詩蘭黛粉持久
# data reading... 38 id: 231143930 CANMAKE血色腮紅
# data reading... 39 id: 231143593 露華濃 無懈可擊loreal無暇完美
# data reading... 40 id: 231143412 ［肉毒懶人包］肉毒價格、效果、劑量、品牌大彙整
# data reading... 41 id: 231143127 不專業彩繪分享
# data reading... 42 id: 231143081 #分享 mac粉霧唇膏 杏桃珊瑚🌷stay curious 923
# data reading... 43 id: 231142957 Essence 限定自然楓彩頰彩盤
# data reading... 44 id: 231142926 #圖 ‼️露華濃Candid無懈可擊粉底液8小實測公開❤️
# data reading... 45 id: 231142902 分享 Neutrogena 素顏霜
# data reading... 46 id: 231142819 美甲初體驗
# data reading... 47 id: 231142811 燒🔥Maybelline超持久霧感液態唇膏 #117先驅者
# data reading... 48 id: 231142805 日本Flowfushi UZU新款眼線筆分享❤️
# data reading... 49 id: 231142594 #問 大家都是如何找到跟自己合拍的隱眼？(海昌/酷柏/嬌生/博士倫)
# data reading... 50 id: 231142541 #閒聊 小樣贈品是你們的煩惱嗎？
# data reading... 51 id: 231142462 夏天防脫妝?
# data reading... 52 id: 231142455 #分享 日常妝容（很多臉照）
# data reading... 53 id: 231142412 #問 Mac刷具187
# data reading... 54 id: 231142357 #討論 Bffect新產品長痘痘？#有皮膚圖
# data reading... 55 id: 231142332 #圖 美甲分享 也跟我分享你們的光療好嗎🥰❤️
# data reading... 56 id: 231142257 火影忍者光療
# data reading... 57 id: 231142092 #心得 近期入手及愛用彩妝+刷具
# data reading... 58 id: 231142068 #請益 灰色系眼影
# data reading... 59 id: 231142014 #情報 #分享 重新上市的Fleur弗珞彩色日拋
# data reading... 60 id: 231142006 #圖 #詳細 來點不一樣的橘 熱帶風情帶起來
# data reading... 61 id: 231142004 essence 楓采頰彩盤，女人味版本配色(???
# data reading... 62 id: 231141908 #圖 日本東京行軍般的行程沒在怕~用完一盒LACELLE心得
# data reading... 63 id: 231141809 #圖 牙齒矯正 整齊但是歪歪的
# data reading... 64 id: 231141745 #請益 請問Dcard碧兒泉小禮物
# data reading... 65 id: 231141706 #分享 好卸又清爽的專科卸妝水
# data reading... 66 id: 231141669 1028暹羅貓眼線液筆
# data reading... 67 id: 231141642 mac fix+ 活力水噴霧
# data reading... 68 id: 231141636 #分享 小屈巡田水小戰績，令人怦然心動的kiss唇膏💄
# data reading... 69 id: 231141601 ❤ 省吃儉用也要買買買的香緹卡鑽石組 ❤
# data reading... 70 id: 231141517 服用口服A酸
# data reading... 71 id: 231141482 台南醫美雷射請益！
# data reading... 72 id: 231141375 #分享 SOFINA  輕盈飽水潤澤組
# data reading... 73 id: 231141328 關於除毛
# data reading... 74 id: 231141324 #分享#敏感肌 兩款常備溫和洗面乳-舒特膚&理膚
# data reading... 75 id: 231141279 #發問 類似唇膏的顏色
# data reading... 76 id: 231141236 分享 BOURJOIS 妙巴黎 特賣會
# data reading... 77 id: 231141231 #圖 讓我驚豔的白泥
# data reading... 78 id: 231141195 #討論 化妝水二次清潔？
# data reading... 79 id: 231141042 想吃下去的羊珞素好用分享~
# data reading... 80 id: 231140948 蘭蔻零粉感
# data reading... 81 id: 231140947 露華濃唇膏選擇
# data reading... 82 id: 231140945 #分享 讓皮膚穩定度up的貝膚黛瑪精華
# data reading... 83 id: 231140935 Maybelline 持妝乳 買一送一
# data reading... 84 id: 231140742 玻尿酸推薦 內有選手🌸
# data reading... 85 id: 231140670 屈臣氏Monday折價序號
# data reading... 86 id: 231140480 隱眼保養液推薦
# data reading... 87 id: 231140104 詢問幽蘭補濕乳霜
# data reading... 88 id: 231139860 尋一瓶有歷史的香水Gucci 6號
# data reading... 89 id: 231139771 美若康隱眼
# data reading... 90 id: 231139508 二手美妝交換/販售
# data reading... 91 id: 231139139 真有人那麼貪小便宜？？
# data reading... 92 id: 231138956 Sk-II 製造日期與活性
# data reading... 93 id: 231138901 #問# l'oreal paradise primer extatic
# data reading... 94 id: 231138823 #問 the ordinary 使用順序
# data reading... 95 id: 231138649 縫雙眼皮後兩眼消腫速度不一
# data reading... 96 id: 231138631 ＃圖 小資女五分鐘好氣色妝容all day實測
# data reading... 97 id: 231138580 香水的家
# data reading... 98 id: 231138315 臉部防曬請益
# data reading... 99 id: 231138185 #情報 momo萊雅品牌周眼唇卸1瓶$112
# data reading... 100 id: 231137891 我用到凹凹的L'oreal
# (101, 10)
#             id                    title  \
# 0    231148004            #請益 無酒精的美白保養品
# 1    231147886           #閒聊 你心目中的刷具之王？
# 2    231147742                       霧眉
# 3    231147734                #問 防曬需要卸嗎
# 4    231147726                雙眼皮膠水好有用！
# ..         ...                      ...
# 96   231138631  ＃圖 小資女五分鐘好氣色妝容all day實測
# 97   231138580                     香水的家
# 98   231138315                   臉部防曬請益
# 99   231138185   #情報 momo萊雅品牌周眼唇卸1瓶$112
# 100  231137891            我用到凹凹的L'oreal
#
#                                                content  \
# 0    我的膚質是敏感肌，想找無酒精的美白保養品😳\n目前只知道BEVY C.美白是無酒精的\nht...
# 1    昨天收到一批受受狼 開箱用覺得刷毛好蘇福啊！\n但心目中刷具之王還是植村秀的55刷無誤！\n...
# 2    想請問一下在基隆或台北有推薦霧眉的店家嗎？\n想去霧眉但找不到合適的店家\n希望有推薦的店家...
# 3    我買了一瓶無色的防曬乳，上網查發現說要卸不卸的回答都有。\n想請問大家擦無色的純防曬乳會卸嗎...
# 4    一直以來我都大小眼一邊內雙一邊外雙，\n\nhttp://i.imgur.com/NNdZJ...
# ..                                                 ...
# 96   嗨嗨～大家好～～～\n今天要來跟大家分享最近的入手的新品\n✨1028 超控油肌近完美飾底乳...
# 97                想看看大家有專門放香水的地方嗎😂最近剛入香水坑想好好保存\n給他舒服的家
# 98   目前手上有兩隻防曬 \n其中有一隻很好奇\n感覺好像沒什麼人（？）提到它\nhttps://...
# 99   半夜睡不著亂滑手機想說看看有啥好買\n發現momo在做巴黎萊雅跟媚比琳的品牌周\n價格低到很...
# 100  第一次發文 排版可能有點不好看\n\n正文\n\n我會買這支其實是因為之前cara有一支推薦...
#
#                                                excerpt  \
# 0    我的膚質是敏感肌，想找無酒精的美白保養品，目前只知道BEVY C.美白是無酒精的，上次看到有...
# 1    昨天收到一批受受狼 開箱用覺得刷毛好蘇福啊！，但心目中刷具之王還是植村秀的55刷無誤！，這把...
# 2    想請問一下在基隆或台北有推薦霧眉的店家嗎？想去霧眉但找不到合適的店家，希望有推薦的店家能與我...
# 3    我買了一瓶無色的防曬乳，上網查發現說要卸不卸的回答都有。想請問大家擦無色的純防曬乳會卸嗎？還...
# 4    一直以來我都大小眼一邊內雙一邊外雙，某天照鏡子突然覺得欸  好像真的差滿多的，就隨便去寶雅買...
# ..                                                 ...
# 96   嗨嗨～大家好～～～今天要來跟大家分享最近的入手的新品，1028 超控油肌近完美飾底乳SPF5...
# 97                  想看看大家有專門放香水的地方嗎最近剛入香水坑想好好保存，給他舒服的家
# 98   目前手上有兩隻防曬，其中有一隻很好奇，感覺好像沒什麼人（？）提到它，這隻 我覺得他一點油感也...
# 99   半夜睡不著亂滑手機想說看看有啥好買，發現momo在做巴黎萊雅跟媚比琳的品牌周，價格低到很驚人...
# 100  第一次發文 排版可能有點不好看，正文，我會買這支其實是因為之前cara有一支推薦mlbb的影...
#
#                     createdAt                 updatedAt forumName forumAlias  \
# 0    2019-04-23T06:54:01.936Z  2019-04-23T06:54:01.936Z        美妝     makeup
# 1    2019-04-23T06:34:34.241Z  2019-04-23T06:34:34.241Z        美妝     makeup
# 2    2019-04-23T06:08:52.937Z  2019-04-23T06:08:52.937Z        美妝     makeup
# 3    2019-04-23T06:06:20.488Z  2019-04-23T06:06:20.488Z        美妝     makeup
# 4    2019-04-23T06:05:07.541Z  2019-04-23T06:06:08.209Z        美妝     makeup
# ..                        ...                       ...       ...        ...
# 96   2019-04-21T18:05:34.152Z  2019-04-22T03:05:00.860Z        美妝     makeup
# 97   2019-04-21T17:55:59.306Z  2019-04-21T17:55:59.306Z        美妝     makeup
# 98   2019-04-21T17:17:58.034Z  2019-04-21T17:17:58.034Z        美妝     makeup
# 99   2019-04-21T17:00:42.202Z  2019-04-21T17:00:42.202Z        美妝     makeup
# 100  2019-04-21T16:22:54.323Z  2019-04-21T16:22:54.323Z        美妝     makeup
#
#     gender  topics
# 0        F      NaN
# 1        F      NaN
# 2        F      NaN
# 3        F      NaN
# 4        F      NaN
# ..     ...      ...
# 96       F      NaN
# 97       F      NaN
# 98       F      NaN
# 99       F      NaN
# 100      F      NaN
#
# [101 rows x 10 columns]

# %% [markdown]
# # ---------------正式版本分隔線---------------
# - 測試版本代號：1.2  2020
# - 正式版本代號：2.03  2021
# - 開發人員： EGG Jerry Three

# %% [markdown]
# dva.x_x 版本開發

# %%
#找到 dav.x_x 發表過的文章

p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/@dva.x_x")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
sel
a=[]
for link in sel:
    a.append(link["href"])
    print(link.get('href')[-9:])
    print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def CatchUser(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'department':rejs['department'],  #for author
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'department':"",    #for author
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# 熱門美妝版測試 (100筆)
url = 'https://www.dcard.tw/@dva.x_x'
#url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=5'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(CatchUser(rejs[i]['id']),ignore_index=True)   #0 - 29
print(df.shape)
#df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(CatchUser(rejs[0]['id']),ignore_index=True) 
#df
print(str(int(df['id'].tail(1))) )

count = 0
delay_choices = [1, 3, 5]  # delay second
delay = random.choice(delay_choices) 

for j in range(1):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    delay = random.choice(delay_choices)
    time.sleep(delay)  
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# slope the title
def CatchPost(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
#CatchPost(234999065)
#url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
url = 'https://www.dcard.tw/_api/posts/235103419'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
url = 'https://www.dcard.tw/_api/posts/234912821'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
# url = 'https://www.dcard.tw/_api/posts/235103302'
resq = requests.get(url)
rejs = resq.json()
rejs

# %% [markdown]
# # --------------- dva.x_x 版本分隔線 ---------------
# - 測試版本代號：Jerry 1.0
# - 開發人員： Jerry

# %%
#test = open("data/test.txt","w",encoding='UTF-8')

# %%
# asb
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=99"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True)   #0 - 29

delay_choices = [1]#, 3, 5, 7,20]  #延遲的秒數
delay = random.choice(delay_choices)  #隨機選取秒數

for j in range(10):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=true&limit=99&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 101 == 0:
            print('第',j,'次執行，data reading...',i,'last',last,'chocice',delay)
    delay = random.choice(delay_choices)  #隨機選取秒數
    time.sleep(delay)  #延遲

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# 熱門美妝版測試 (100筆)
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']),ignore_index=True)   #0 - 29
    if i % 20 == 0:
        print('data reading...',i)
print(df.shape)
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
#last = str(int(df['ID'].tail(1))) #last dt
#last

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df['ID'].tail(1))) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&before=' + last
    #url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 10 == 0:
            print('第',j,'次執行，data reading...',i)
            
print(df.shape)
df

# %%
last = str(int(df['ID'].tail(1)))
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df

# %%
# 熱門美妝版測試 (100筆)

for i in range(10):
    last = str(int(df['ID'].tail(1)))
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    df = pd.DataFrame()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']),ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
    print(df.shape)

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df

# 99	235031315	#請益 #問 LA girl 遮瑕挑色

# %%
last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID '235031315'
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)


df

# %%
#df

# %%
##ok ^
for j in range(3):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)
#df

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
print(df.shape)
df

# %%
df.to_excel('data/Dcard_markeup.excel', index=False)

# %% [markdown]
# 欄位	說明	備註
# ID	編號
# title	標題
# content	內容
# excerpt	摘要
# createdAt	發布時間
# updatedAt	更新時間
# commentCount	留言數
# forumName	分類	中文
# forumAlias	分類	英文
# gender	性別
# likeCount	心情數量
# reactions	心情細項	把以上心情細分為「愛心」、「哈哈」、「跪」、「森77」、「驚訝」等類型
# topics	標籤

# %%
# 固定碼測試
def Catch_test(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )
Catch_test(235020702)
