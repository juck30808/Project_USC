# %% [markdown]
# 根據把首頁往下滑，發現網站會對server送一個GET請求下一個30篇文章
# - 2018(G) https://ithelp.ithome.com.tw/articles/10203216
# - 2019(G) https://tlyu0419.github.io/2019/04/06/Crawl-Dcard/
# - 2020 https://blog.jiatool.com/posts/dcard_api_v2/

# %% [markdown]
# ### API root
#
# - 看板資訊 http://dcard.tw/_api/forums
# - 文章資訊 http://dcard.tw/_api/forums/{看板名稱}/posts
# - 文章內文	http://dcard.tw/_api/posts/{文章編號}
# - 文章內引用連結	http://dcard.tw/_api/posts/{文章編號}/links
# - 文章內留言	http://dcard.tw/_api/posts/{文章編號}/comments
#
# ### API wirte
# - 文章數量 https://www.dcard.tw/_api/posts?limit=100
# - 文章分頁 http://dcard.tw/_api/posts/?before=文章id (before 回傳由新到舊 after舊到新)
# - 文章留言 http://dcard.tw/_api/posts/文章id/comments
# - 留言分頁 http://dcard.tw/_api/posts/文章id/comments?after=floor數字
# - 熱門文章 https://dcard.tw/_api/posts?popular=true
#
# ### others
# 文章資訊(meta) 與 文章內留言 預設使用熱門度 (popularity) 作為排序，而且一次請求 (request) 中只回應 30 筆。
# * 想要讓這兩項使用 時間 排序，可在 GET 參數中加入 popular=false
# * 欲取得更多的 文章資訊(meta)，可以使用 before={某文章編號}來獲得早於 #{某文章編號} 的另外 30 筆 資訊。
# * 欲取得更多的 文章內留言，可以使用 after={某樓層} 來獲得大於 #{某樓層} 的另外 30 筆 留言。

# %%
import requests
import json
import pandas as pd    # 引用套件並縮寫為 pd
from bs4 import BeautifulSoup
# https://www.dcard.tw/f/makeup

# %% [markdown]
# GET 美妝版首頁，Use BeautifulSoup with html, wrtie a txt

# %%
p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/f/makeup")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
#sel

#for link in sel:
#    a.append(link["href"])
    #print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def Catch(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# KeyError: 'id'
# Oh！文章不見了 這篇文章已被作者刪除。 按這裡 看更多文章吧
# https://www.dcard.tw/f/makeup/p/235079399
# Catch(235079399)
# url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=233254532"

# %%
import random
import time

#url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=229872382" 
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True) 
#df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-3f3ab4390423> in <module>
#       5 url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=229872382"
#       6 resq = requests.get(url)
# ----> 7 rejs = resq.json()
#       8 df = pd.DataFrame()
#       9 df = df.append(Catch(rejs[0]['id']),ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
count = 0
delay_choices = [15,30,32]  # delay second
delay = random.choice(delay_choices) 

for j in range(300):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    delay = random.choice(delay_choices)
    time.sleep(delay)  
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    df.to_csv(str(j) + '_Dcard.csv', index=False)
    
df.to_csv('data/Dcard_makeup.csv', index=False) #encoding = "UTF-8"
print(df.shape)
df
# Out:
# 229920083
# data reading... 1 id: 229920082 #圖多 #文長 2017/10～2018/10一年份空空賞不專業分享💫
# data reading... 2 id: 229919881 對於整容的看法
# data reading... 3 id: 229919844 Mac超激光有人這樣嗎..
# data reading... 4 id: 229919842 眉毛求批
# data reading... 5 id: 229919619 ＃圖 ＃周慶戰利品   契爾氏冰河醣保濕霜組
# data reading... 6 id: 229919517 #問 粉棕色/粉褐色唇彩
# data reading... 7 id: 229919513 幫選色 Romand唇釉
# data reading... 8 id: 229919342 『情報』KATE眼影 新品預購🔥
# data reading... 9 id: 229919290 新手眉毛求批
# data reading... 10 id: 229919193 尋找森田藥妝卸妝水😭
# data reading... 11 id: 229918793 痘痘
# data reading... 12 id: 229918765 詢問這瓶洗面乳哪裡買的到？
# data reading... 13 id: 229918564 #分享 很滿意的美甲（台中）
# data reading... 14 id: 229918360 #圖 彩妝品幫選擇🙏🏼
# data reading... 15 id: 229918173 問 這款唇膏有人有用過嗎？
# data reading... 16 id: 229918151 ：：關於口服A酸保養
# data reading... 17 id: 229918130 #圖 MISSHA 新品Glow me水光奶油肌系列分享
# data reading... 18 id: 229917753 12月日雜贈品-GA唇膏、SUQQU粉底霜
# data reading... 19 id: 229917672 分享萬聖節妝容（附加3ce唇釉試色）
# data reading... 20 id: 229917609 #割雙眼皮 照片分享 噁圖慎入
# data reading... 21 id: 229917602 應該試試的美甲好物！
# data reading... 22 id: 229917340 innisfree公館要開了！！！
# data reading... 23 id: 229917128 #芳療 肌膚回春的好朋友-橙花
# data reading... 24 id: 229917100 #自然光澤感 秋冬氣墊推薦/Jill Stuart
# data reading... 25 id: 229916987 #分享 小屈開架優惠
# data reading... 26 id: 229916858 原本以為再也不想用抽取面膜了說
# data reading... 27 id: 229916804 #圖 超美自帶光圈❤植村秀天生光圈氣墊+聚光唇萃分享
# data reading... 28 id: 229916534 Versace 香水
# data reading... 29 id: 229916353 小紅書紅爆的星鑽赤茶色
# data reading... 30 id: 229915907 幾款絕美粉底!!!嬌蘭24K\Lancome\Ysl\BB\GA
# data reading... 31 id: 229915895 embryolisse 包裝
# data reading... 32 id: 229915789 Fit me 反孔特霧無瑕嫩粉餅 厭世8hr實測
# data reading... 33 id: 229915742 #問
# data reading... 34 id: 229915655 抗痘保養篇
# data reading... 35 id: 229915653 #圖 FOREO LUNA MINI2迷你淨透潔面儀開箱
# data reading... 36 id: 229915628 美甲經驗分享
# data reading... 37 id: 229915471 敏感肌用碧兒泉刺癢
# data reading... 38 id: 229915411 Essence柔霧粉底液詢問
# data reading... 39 id: 229915394 #圖 #週年慶 防細紋的蘭蔻眼霜組合！
# data reading... 40 id: 229915230 wet n wild 唇膏試色
# data reading... 41 id: 229915126 敏弱肌換季維持穩定的大功臣
# data reading... 42 id: 229915083 #情報 &ROSY日雜送GA唇膏#503
# data reading... 43 id: 229915051 #妝記 COLOURPOP 12色眼影盤+15色眼影盤+眼影蜜試色
# data reading... 44 id: 229915039 #問 雅詩蘭黛水粉底搭氣墊粉撲
# data reading... 45 id: 229915011 卸妝水推薦
# data reading... 46 id: 229915002 #請益 氣墊粉餅推薦 有選手～
# data reading... 47 id: 229914984 #請益 眉毛雨衣的選擇
# data reading... 48 id: 229914970 不專業隱眼分享
# data reading... 186 id: 229900979 新手眉毛求批
# data reading... 187 id: 229900776 有滿意的開架保濕底妝🌟Loreal特潤光感粉底液
# data reading... 188 id: 229900669 #問MAC 子彈頭新版包裝（加拿大版）
# data reading... 189 id: 229900437 分享 Chanel獅子圖騰亮采盤
# data reading... 190 id: 229900203 美妝youtuber推薦
# data reading... 191 id: 229900179 #週年慶 Bobbi brown/lancome 小開箱（偷渡非專櫃商品）
# data reading... 192 id: 229900076 Maybelline又出一波新色唇膏
# data reading... 193 id: 229899979 最美的香腸嘴
# data reading... 194 id: 229899858 #閒聊 植村秀官網買天生光圈組
# data reading... 195 id: 229899789 #問 Maybelline 眼線液
# data reading... 196 id: 229899751 #問 專櫃小樣
# data reading... 197 id: 229899648 情報～Integrate免費粉底刷
# data reading... 198 id: 229899626 新手眼妝求批TT
# data reading... 199 id: 229899625 不專業分享 手邊的唇膏刷色！
# data reading... 200 id: 229899499 #問  混合偏乾的專櫃粉底液
# 229899499
# data reading... 201 id: 229899409 #小開箱 #雪花秀 #週年慶 都入手了什麼
# data reading... 202 id: 229899356 試用後被燒到🔥💃🏻碧兒泉晶透奇蹟水
# data reading... 203 id: 229899331 幫選唇膏色
# data reading... 204 id: 229899310 歐美免費刷具
# data reading... 205 id: 229899239 #求問 這隻口紅是哪牌的
# data reading... 206 id: 229899234 #分享 這一年來的開架卸妝好夥伴🎉
# data reading... 207 id: 229899222 #請益 持妝氣墊粉餅 內有選手
# data reading... 208 id: 229899025 [CANMAKE]完美霧面03&設計師18眼影盤刷色比較
# data reading... 209 id: 229898998 追劇之餘誰也忘了保養
# data reading... 210 id: 229898912 ＃圖 讓妝服服貼貼的好物kiehl’s紫鳶肌活露
# data reading... 211 id: 229898724 2018週年慶分享♥️
# data reading... 212 id: 229898555 SOFINA Primavista 漾緁輕妝綺肌長效粉餅 進化版 體驗開箱囉！
# data reading... 213 id: 229898265 Dcard辦這活動是在幹嘛啦😂
# data reading... 214 id: 229898222 控油蜜粉
# data reading... 215 id: 229898203 #幫選 選擇障礙～～
# data reading... 216 id: 229897974 美妝youtuber 個人淺見與分享
# data reading... 217 id: 229897893 #問 專櫃到貨很久沒有拿
# data reading... 218 id: 229897735 問 Essence單顆眼影 只有表面有亮粉？
# data reading... 219 id: 229897680 #想問這款隱眼
# data reading... 220 id: 229897278 代Po 求幫忙 蘿拉密斯週年慶優惠。
# data reading... 221 id: 229897179 MAC Red rock
# data reading... 222 id: 229897109 底妝投資
# data reading... 223 id: 229896999 #問 #新手白痴  clio膚色遮瑕
# data reading... 224 id: 229896871 問，清潔液顏色
# data reading... 225 id: 229896865 Kiss me花漾美姬防水睫毛膏-莓果紫
# data reading... 226 id: 229896861 #問 植村秀55刷適用粉底液
# data reading... 227 id: 229896695 保養品跟化妝品花費
# data reading... 228 id: 229896621 #問 mac170 vs 植村秀55刷
# data reading... 229 id: 229896601 #請益  橘色系唇膏
# data reading... 230 id: 229896493 #分享 #MAC絲柔粉霧唇膏收五色
# data reading... 231 id: 229896332 ＃圖 貴的保養品真的不一樣 周慶入手GA奇蹟精萃露
# data reading... 372 id: 229883360 L’ORÉAL 金管唇膏839試色
# data reading... 373 id: 229883344 #問#保養 皮膚缺水 卻又大量出油
# data reading... 374 id: 229883299 NARS 剁手開箱文
# data reading... 375 id: 229883234 #問 integrate彎彎翹麗vs1028飛激長
# data reading... 376 id: 229883010 |分享|#更實擦_我的秋冬開架唇膏分享#橘/土/紅棕/奶茶色系#試色
# data reading... 377 id: 229882914 #閒聊 植村秀狠霧持色染唇露生大火
# data reading... 378 id: 229882896 #請益 Dior、Mac、Nars專櫃粉底選擇🙏🏻
# data reading... 379 id: 229882689 #分享 Laura mercier週年慶好划算之囤貨組合
# data reading... 380 id: 229882679 新手眉毛  求批
# data reading... 381 id: 229882589 #露華濃魔幻月光腮紅盤001 #包裝生火🔥 #柔霧唇膏048
# data reading... 382 id: 229882560 六點式縫雙眼皮有人完全沒掉嗎
# data reading... 383 id: 229882537 埃及？！PARTY妝分享
# data reading... 384 id: 229882482 Etude house 秋冬眼影 迷你唇膏開箱
# data reading... 385 id: 229882431 #香水 《茶香特輯2》-伯爵茶
# data reading... 386 id: 229882427 COLOURPOP SHE 不日常的妝
# data reading... 387 id: 229882417 植村秀週年慶敗家分享(全能奇蹟家族+保濕噴霧)
# data reading... 388 id: 229882370 #心得 韓系眼妝與博士倫LACELLE意外的搭
# data reading... 389 id: 229882366 有人也是閃光皮膚比較好的嗎＠＠？
# data reading... 390 id: 229882361 燒🔥Bobbi Brown金緻極霧唇釉
# data reading... 391 id: 229882326 說好的77折呢⋯
# data reading... 392 id: 229882272 #圖 溫柔小姊姊般的Dior藍星169(偷渡潤唇#004)
# data reading... 393 id: 229882196 #情報 pony氣墊買一送一
# data reading... 394 id: 229882180 理膚寶水週年慶
# data reading... 395 id: 229882122 水洗式面膜 分享🌸
# data reading... 396 id: 229882091 #隱形眼鏡 GEO 日拋 Eyeniq系列 Glam Brown 實戴
# data reading... 397 id: 229881993 #週年慶 #揪團 #bobbibrown(二更+表單)開放到禮拜四晚上
# data reading... 398 id: 229881919 Opt 晨霧青 月拋試戴
# data reading... 399 id: 229881884 ETUDE HOUSE nuts&fruits早秋霧面唇膏 迷你唇膏
# data reading... 400 id: 229881869 SOFINA漾緁改版粉底液一日不吸油挑戰
# 229881869
# data reading... 401 id: 229881710 請問台中有沒有推薦的嫁接睫毛店
# data reading... 402 id: 229881657 ＃幫選 etude house BE119 v.s. loreal小棕皮 292
# data reading... 403 id: 229881556 #情報#新品 fit me反孔特霧無暇嫩粉餅😍
# data reading... 404 id: 229881499 粉底液選擇障礙
# data reading... 405 id: 229881489 #更 Innisfree 贈品缺貨替代標準到底是什麼
# data reading... 406 id: 229881488 sabon開箱分享+Aveda小激推
# data reading... 407 id: 229881443 美到只能收編♥️Loreal小棕皮#292
# data reading... 408 id: 229881385 #問卷調查 理膚寶水
# data reading... 409 id: 229881347 【詢問】莎樂菲SaLafe plus臉部制汗凝膠
# data reading... 410 id: 229881339 推一個#innisfree果漾精油唇粹👄
# data reading... 411 id: 229881203 對於修眉的問題
# data reading... 412 id: 229881146 SEPHORA 10/26開始打8折
# data reading... 413 id: 229880895 蜜粉 粉餅
# data reading... 414 id: 229880892 新手眉毛 求批
# data reading... 415 id: 229880789 #問#妝前
# data reading... 416 id: 229880631 妮維雅長毛
# data reading... 417 id: 229880551 請問鼻子很油還會脫皮⋯
# data reading... 418 id: 229880531 蜜粉餅Vs粉餅
# data reading... 419 id: 229880365 化妝與自信的關係
# data reading... 420 id: 229880276 初學化妝時做過的蠢事
# data reading... 421 id: 229880087 在韓矯正牙齒問題
# data reading... 422 id: 229880027 超強不掉色眉筆
# data reading... 423 id: 229879839 契爾氏週年慶！
# data reading... 424 id: 229879668 VDL妝前乳
# data reading... 425 id: 229879408 萬聖節妝❤️🖤
# data reading... 426 id: 229879395 Colourpop she 體驗 #指教
# data reading... 427 id: 229879357 #Ohana mahaalo 香味挑選
# data reading... 428 id: 229879219 #黑特 台中蘭蔻櫃姐？
# data reading... 429 id: 229878886 #圖 日常保養分享🌻
# data reading... 430 id: 229878849 #問 粉底液選擇
# data reading... 431 id: 229878737 更%咬了23年的指甲☹️光療養甲中
# data reading... 432 id: 229878729 #問 與畢卡索 207a相似的￼眼影刷
# data reading... 433 id: 229878640 #分享 開架/日系愛用臉部保養分享✏️
# data reading... 434 id: 229878601 #問 Foreo官網的價格
# data reading... 435 id: 229878497 秋季皮膚好朋友♥
# data reading... 436 id: 229878474 #問 #2018 ipsa 週年慶 #天母sogo
# data reading... 437 id: 229878437 #試色 Loreal純色訂製唇膏柔霧款#203#208#214#217
# data reading... 438 id: 229878245 #問 洗眉推薦
# data reading... 439 id: 229878170 2018週年慶碧兒泉戰利品分享
# data reading... 440 id: 229878116 在韓矯正牙齒問題
# data reading... 441 id: 229878110 植村秀 狠霧持色染唇露 不專業試色🔥
# data reading... 442 id: 229877823 #圖 #試色 CLIO 08楓紅焦糖裸
# data reading... 443 id: 229877657 #情報 屈臣氏開架彩妝77折
# data reading... 444 id: 229877649 Addiction 批號怎麼看😭
# data reading... 445 id: 229877601 週年慶戰利品分享🎶（專櫃慎入）
# data reading... 446 id: 229877547 banila co 空氣感提亮持妝蜜粉 “控油款”
# data reading... 447 id: 229877534 微毛躁女孩的免沖洗護髮蜜糖💁
# data reading... 448 id: 229877469 The ordinary 角鯊會致粉刺嗎？
# data reading... 449 id: 229877420 #問 Flormar奧賽美術眼影盤
# data reading... 450 id: 229877340 #問 Burning love和D for danger的差別 #MAC
# data reading... 451 id: 229877103 #分享 #Labo labo #L'EGERE 水凝露系列
# data reading... 452 id: 229877065 卸妝＋潔顏選手心得 兼請益
# data reading... 453 id: 229877036 Wet n Wild 眼妝分享🌹Rose in the air🌹
# data reading... 454 id: 229876939 推♥️曼秀雷敦 抗痘粉狀調理水
# data reading... 455 id: 229876937 旅行只帶白松露一瓶搞定保養部分
# data reading... 456 id: 229876880 品木宣言週年慶分享💚
# data reading... 457 id: 229876550 關於USB熱敷眼罩Q&A
# data reading... 458 id: 229876537 ＃分享 品木週年慶之必買👣漫步在雲端的前世今生
# data reading... 459 id: 229876525 萬聖節彩妝❤🖤
# data reading... 460 id: 229876507 #情報 屈臣氏MOONSHOT3折出清
# data reading... 461 id: 229876491 W lab 精華開孔內的環斷了⋯算瑕疵嗎？
# data reading... 462 id: 229876443 舒力達（Soolantra)在義大利好便宜！
# data reading... 463 id: 229876411 7-11卡娜赫拉護唇膏使用心得分享🐰
# data reading... 464 id: 229876309 #問 a'pieu 我的小睫毛膏
# data error... 64 J: 4
# data reading... 465 id: 229876294 洗臉機心得
# data reading... 466 id: 229876163 眼線膠畫俐落眉
# data error... 66 J: 4
# data reading... 467 id: 229876107 #超快到🤟🏻 薇姿MOMO週年慶回購M89溫泉水🤣
# data reading... 468 id: 229875925 #問 mac 晶亮潤膚乳液 色號選擇
# data reading... 469 id: 229875860 終於成為花農🌹小花腮紅盤刷色分享💐
# data reading... 470 id: 229875781 問 crest美白牙貼
# data reading... 471 id: 229875617 請問有卡友們使用過這牌的養髮液嗎？
# data reading... 472 id: 229875576 what's in my 長途飛機保養包🛫
# data reading... 473 id: 229875410 週年慶拿到一堆欠貨單😭
# data reading... 474 id: 229875369 #圖 #試色 BBIA 霧面唇膏04
# data reading... 475 id: 229875154 #情報 solone新款眼影盒
# data reading... 476 id: 229875142 衝innisfree週年慶就為了潤娥歐逆的美照
# data reading... 477 id: 229875068 問 隱眼款式
# data reading... 478 id: 229875017 #圖 #蘭芝 意外好用の我的ID是睡美人
# data reading... 479 id: 229874558 #更#黑特 高雄漢神巨蛋 倩碧 櫃哥
# data reading... 480 id: 229874498 被誰燒成灰燼後找到命定粉底
# data reading... 481 id: 229874389 未來美溫感雙效洗臉機vs Lumispa
# data reading... 482 id: 229874353 頰彩盤選擇
# data reading... 483 id: 229874332 #圖 認真覺得3INA粉底液很欠敗
# data reading... 484 id: 229874307 有推薦的敏感肌保濕面膜嗎
# data reading... 485 id: 229874074 （更）黑特SK-ll （文長）
# data error... 85 J: 4
# data reading... 486 id: 229873745 #最終更 大眼校際爭霸賽👁用眼睛為全校爭一口氣～優勝學校將get博士倫精美大眼睛禮盒(瑞霖水漾清新多效保養液120ml $1兌換券50份、卡娜赫拉提袋100份)！
# data reading... 487 id: 229873744 SOFINA Primavista 漾緁輕妝綺肌長效粉底液 進化版 體驗開箱囉！
# data reading... 488 id: 229873652 #請益 covermark 柔紗粉蕊
# data reading... 489 id: 229873332 求唇膏色號！
# data reading... 490 id: 229873216 #請益 資生堂新品
# data reading... 491 id: 229873109 #問 痘痘粉刺毛孔
# data reading... 492 id: 229873081 #情報 3CE 2018/10/18限時一天全球免運
# data reading... 493 id: 229873016 有種東西叫眼唇卸妝液
# data reading... 494 id: 229872942 關於隆鼻 陳振坤醫生 荊偉政醫生
# data reading... 495 id: 229872900 #情報 新光三越的美妝盒2018 Oct.
# data reading... 496 id: 229872760 什麼樣的香水最適合用在男生的身上
# data reading... 497 id: 229872558 #問fenty beauty 新品
# data reading... 498 id: 229872492 #隱眼#小直徑 那年愛上的小直徑
# data reading... 499 id: 229872382 #尋找 錦覓同款唇膏
# data reading... 500 id: 229872268 #圖 #混合肌 肌膚檢測與簡單保養分享 ：）
# 229872268
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-cb9b2b199aa5> in <module>
#       8     url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
#       9     resq = requests.get(url)
# ---> 10     rejs = resq.json()
#      11     delay = random.choice(delay_choices)
#      12     time.sleep(delay)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import random
import time

count = 0
delay_choices = [3,7,5]  # delay second
delay = random.choice(delay_choices) 

for j in range(5):
    print('data reading...',j,delay)
    delay = random.choice(delay_choices)
    time.sleep(delay)

# %% [markdown]
# # ---------------正式版本分隔線---------------
# - 測試版本代號：1.2  2020
# - 正式版本代號：2.03  2021
# - 開發人員： EGG Jerry Three

# %% [markdown]
# dva.x_x 版本開發

# %%
#找到 dav.x_x 發表過的文章

p = requests.Session()                             # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/@dva.x_x")  # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
sel
a=[]
for link in sel:
    a.append(link["href"])
    print(link.get('href')[-9:])
    print('https://www.dcard.tw'+link.get('href'))

# %%
# slope the title
def CatchUser(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'department':rejs['department'],  #for author
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'department':"",    #for author
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'department', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
# 熱門美妝版測試 (100筆)
url = 'https://www.dcard.tw/@dva.x_x'
#url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=5'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(CatchUser(rejs[i]['id']),ignore_index=True)   #0 - 29
print(df.shape)
#df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=false&limit=1"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(CatchUser(rejs[0]['id']),ignore_index=True) 
#df
print(str(int(df['id'].tail(1))) )

count = 0
delay_choices = [1, 3, 5]  # delay second
delay = random.choice(delay_choices) 

for j in range(1):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    print(last)
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=false&limit=100&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        count = count+1
        print('data reading...',count,'id:',rejs[i]['id'],rejs[i]['title'])
    delay = random.choice(delay_choices)
    time.sleep(delay)  
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# slope the title
def CatchPost(num):
    try:
        url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
        resq = requests.get(url)
        rejs = resq.json()
        return(pd.DataFrame(
            data=
            [{'id':rejs['id'],
              'title':rejs['title'],
              'content':rejs['content'],
              'excerpt':rejs['excerpt'],
              'createdAt':rejs['createdAt'],
              'updatedAt': rejs['updatedAt' ],
              'forumName':rejs['forumName'],
              'forumAlias':rejs['forumAlias'],
              'gender':rejs['gender'],
              'topics':rejs['topics']}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )
    except:
        print('data error...',i,'J:',j)
        return(pd.DataFrame(
            data=
            [{'id':"",
              'title':"",
              'content':"",
              'excerpt':"",
              'createdAt':"",
              'updatedAt': "",
              'forumName':"",
              'forumAlias':"",
              'gender':"",
              'topics':""}],
            columns=['id', 'title', 'content', 'excerpt', 'createdAt', 
                     'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
              )

# %%
#CatchPost(234999065)
#url = 'https://www.dcard.tw/_api/posts/'+str(num)  #api post with ID
url = 'https://www.dcard.tw/_api/posts/235103419'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
url = 'https://www.dcard.tw/_api/posts/234912821'
resq = requests.get(url)
rejs = resq.json()
rejs

# %%
# url = 'https://www.dcard.tw/_api/posts/235103302'
resq = requests.get(url)
rejs = resq.json()
rejs

# %% [markdown]
# # --------------- dva.x_x 版本分隔線 ---------------
# - 測試版本代號：Jerry 1.0
# - 開發人員： Jerry

# %%
#test = open("data/test.txt","w",encoding='UTF-8')

# %%
# asb
import random
import time

url = "http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=99"
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df = df.append(Catch(rejs[0]['id']),ignore_index=True)   #0 - 29

delay_choices = [1]#, 3, 5, 7,20]  #延遲的秒數
delay = random.choice(delay_choices)  #隨機選取秒數

for j in range(10):
    last = str(int(df['id'].tail(1))) # 找出爬出資料的最後一筆ID
    url = "https://www.dcard.tw/_api/forums/makeup/posts?popular=true&limit=99&before=" + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 101 == 0:
            print('第',j,'次執行，data reading...',i,'last',last,'chocice',delay)
    delay = random.choice(delay_choices)  #隨機選取秒數
    time.sleep(delay)  #延遲

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
print(df.shape)
df

# %%
# 熱門美妝版測試 (100筆)
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']),ignore_index=True)   #0 - 29
    if i % 20 == 0:
        print('data reading...',i)
print(df.shape)
df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df
# 99	235031315	#請益 #問 LA girl 遮瑕挑色
# 235066991

# %%
#last = str(int(df['ID'].tail(1))) #last dt
#last

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df['ID'].tail(1))) # 找出爬出資料的最後一筆ID
    url = 'https://www.dcard.tw/_api/posts?popular=true&before=' + last
    #url = 'https://www.dcard.tw/_api/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 10 == 0:
            print('第',j,'次執行，data reading...',i)
            
print(df.shape)
df

# %%
last = str(int(df['ID'].tail(1)))
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
df

# %%
# 熱門美妝版測試 (100筆)

for i in range(10):
    last = str(int(df['ID'].tail(1)))
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    df = pd.DataFrame()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']),ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
    print(df.shape)

df.to_csv('data/Op_Dcard_markeup.csv', index=False)
df

# 99	235031315	#請益 #問 LA girl 遮瑕挑色

# %%
last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID '235031315'
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
resq = requests.get(url)
rejs = resq.json()
for i in range(len(rejs)):
    df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)


df

# %%
#df

# %%
##ok ^
for j in range(3):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
print(df.shape)
#df

# %%
# 透過迴圈讀取10*100篇文章，若需讀取更多資料，可以將range(10)中的數值提升
for j in range(10):
    last = str(int(df.tail(1).ID)) # 找出爬出資料的最後一筆ID
    url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true&limit=100&before=' + last
    resq = requests.get(url)
    rejs = resq.json()
    for i in range(len(rejs)):
        df = df.append(Catch(rejs[i]['id']), ignore_index=True)
        if i % 20 == 0:
            print('data reading...',i)
print(df.shape)
df

# %%
df.to_excel('data/Dcard_markeup.excel', index=False)

# %% [markdown]
# 欄位	說明	備註
# ID	編號
# title	標題
# content	內容
# excerpt	摘要
# createdAt	發布時間
# updatedAt	更新時間
# commentCount	留言數
# forumName	分類	中文
# forumAlias	分類	英文
# gender	性別
# likeCount	心情數量
# reactions	心情細項	把以上心情細分為「愛心」、「哈哈」、「跪」、「森77」、「驚訝」等類型
# topics	標籤

# %%
# 固定碼測試
def Catch_test(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )
Catch_test(235020702)
