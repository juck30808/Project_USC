# %%
import requests
import json
import pandas as pd    # 引用套件並縮寫為 pd
from bs4 import BeautifulSoup
# https://www.dcard.tw/f/makeup

# %% [markdown]
# GET 美妝版首頁，Use BeautifulSoup with html, wrtie a txt

# %%
test = open("data/test.txt","w",encoding='UTF-8')

p = requests.Session()                            # 把這一次的request都算在同一個session裡
url=requests.get("https://www.dcard.tw/f/makeup") # 請求的網址
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("h2.tgn9uw-2 a")
a=[]
for link in sel:
    a.append(link["href"])
    print('https://www.dcard.tw'+link.get('href'))
# Out:
# https://www.dcard.tw/f/makeup/p/235022153
# https://www.dcard.tw/f/makeup/p/235021477
# https://www.dcard.tw/f/makeup/p/235025010
# https://www.dcard.tw/f/makeup/p/235022346
# https://www.dcard.tw/f/makeup/p/235021551
# https://www.dcard.tw/f/makeup/p/235026845
# https://www.dcard.tw/f/makeup/p/235025318
# https://www.dcard.tw/f/makeup/p/235021107
# https://www.dcard.tw/f/makeup/p/235023535
# https://www.dcard.tw/f/makeup/p/235025794
# https://www.dcard.tw/f/makeup/p/235026239
# https://www.dcard.tw/f/makeup/p/235029187
# https://www.dcard.tw/f/makeup/p/235024053
# https://www.dcard.tw/f/makeup/p/235028318
# https://www.dcard.tw/f/makeup/p/235029094
# https://www.dcard.tw/f/makeup/p/235023273
# https://www.dcard.tw/f/makeup/p/235021138
# https://www.dcard.tw/f/makeup/p/235024620
# https://www.dcard.tw/f/makeup/p/235027858
# https://www.dcard.tw/f/makeup/p/235024257
# https://www.dcard.tw/f/makeup/p/235023687
# https://www.dcard.tw/f/makeup/p/235025935
# https://www.dcard.tw/f/makeup/p/235024483
# https://www.dcard.tw/f/makeup/p/235024986
# https://www.dcard.tw/f/makeup/p/235023805
# https://www.dcard.tw/f/makeup/p/235024413
# https://www.dcard.tw/f/makeup/p/235023881
# https://www.dcard.tw/f/makeup/p/235029001
# https://www.dcard.tw/f/makeup/p/235025212
# https://www.dcard.tw/f/makeup/p/235024398

# %%
#a
url = "https://www.dcard.tw"+ a[1]
url
# Out:
# 'https://www.dcard.tw/f/makeup/p/235021477'

# %% [markdown]
# 根據把首頁往下滑，發現網站會對server送一個GET請求下一個30篇文章
# - 2018(G) https://ithelp.ithome.com.tw/articles/10203216
# - 2019(G) https://tlyu0419.github.io/2019/04/06/Crawl-Dcard/
# - 2020 https://blog.jiatool.com/posts/dcard_api_v2/

# %% [markdown]
# ### API root
#
# - 看板資訊 http://dcard.tw/_api/forums
# - 文章資訊 http://dcard.tw/_api/forums/{看板名稱}/posts
# - 文章內文	http://dcard.tw/_api/posts/{文章編號}
# - 文章內引用連結	http://dcard.tw/_api/posts/{文章編號}/links
# - 文章內留言	http://dcard.tw/_api/posts/{文章編號}/comments
#
# ### API wirte
# - 文章數量 https://www.dcard.tw/_api/posts?limit=100
# - 文章分頁 http://dcard.tw/_api/posts/?before=文章id (before 回傳由新到舊 after舊到新)
# - 文章留言 http://dcard.tw/_api/posts/文章id/comments
# - 留言分頁 http://dcard.tw/_api/posts/文章id/comments?after=floor數字
# - 熱門文章 https://dcard.tw/_api/posts?popular=true
#
# ### others
# 文章資訊(meta) 與 文章內留言 預設使用熱門度 (popularity) 作為排序，而且一次請求 (request) 中只回應 30 筆。
# * 想要讓這兩項使用 時間 排序，可在 GET 參數中加入 popular=false
# * 欲取得更多的 文章資訊(meta)，可以使用 before={某文章編號}來獲得早於 #{某文章編號} 的另外 30 筆 資訊。
# * 欲取得更多的 文章內留言，可以使用 after={某樓層} 來獲得大於 #{某樓層} 的另外 30 筆 留言。

# %%
def Catch(ID):
    url = 'https://www.dcard.tw/_api/posts/'+str(ID)
    requ = requests.get(url)
    rejs = requ.json()
    #rejs
    return(pd.DataFrame(
        data=
        [{'ID':rejs['id'],
          'title':rejs['title'],
          'content':rejs['content'],
          'excerpt':rejs['excerpt'],
          'createdAt':rejs['createdAt'],
          'updatedAt': rejs['updatedAt' ],
          'forumName':rejs['forumName'],
          'forumAlias':rejs['forumAlias'],
          'gender':rejs['gender'],
          'topics':rejs['topics']}],
        columns=['ID', 'title', 'content', 'excerpt', 'createdAt', 
                 'updatedAt', 'forumName', 'forumAlias','gender', 'topics '])
          )
Catch(235020702)
# Out:
#           ID         title                                            content  \
# 0  235020702  發現冬天好適合用粉霜喔!  入冬後我臉已開始乾TT\n之前夏天用MUF粉餅 遮瑕力跟控油力都不錯\n但冬天用真的不夠保濕...
#
#                                              excerpt  \
# 0  入冬後我臉已開始乾TT，之前夏天用MUF粉餅 遮瑕力跟控油力都不錯，但冬天用真的不夠保濕，最...
#
#                   createdAt                 updatedAt forumName forumAlias  \
# 0  2020-12-21T02:26:52.040Z  2020-12-21T02:34:47.300Z        美妝     makeup
#
#   gender  topics
# 0      F      NaN

# %%
url = 'https://www.dcard.tw/_api/posts/235020702'
requ = requests.get(url)
rejs = requ.json()
#rejs

# %%
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true'
requ = requests.get(url)
rejs = requ.json()
rejs
# Out:
# [{'id': 235022153,
#   'title': '❄️聖誕妝容推薦❄️ 準備漂亮過節讓你 bling bling 惹人愛！',
#   'excerpt': '這週就是聖誕節惹️，各位卡友們餐廳跟交換禮物都準備好了！，現在應該是萬事俱備 只欠東風，是聖誕妝容啦！！，來～不用擔心，小天使幫各位整理了卡友們分享的聖誕妝容，這篇真的要好好閱讀  當天亮麗登場！，這邊',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': True,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T07:07:47.084Z',
#   'updatedAt': '2020-12-21T10:13:21.728Z',
#   'commentCount': 10,
#   'likeCount': 278,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['妝容', '分享', '聖誕妝', '美妝小天使', '精華文'],
#   'meta': {'layout': 'classic', 'isModerator': True},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'D',
#   'school': '美妝小天使',
#   'department': 'makeup_angel',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6b76144f-fe2b-4346-8d59-e9c4eca4ce65',
#     'url': 'https://i.imgur.com/JGqeHb2l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/JGqeHb2l.jpg',
#     'thumbnail': 'https://i.imgur.com/JGqeHb2l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T07:07:47.084Z',
#     'updatedAt': '2020-12-21T10:13:21.728Z',
#     'width': 414,
#     'height': 310},
#    {'id': '6b76144f-fe2b-4346-8d59-e9c4eca4ce65',
#     'url': 'https://i.imgur.com/JGqeHb2.jpg',
#     'normalizedUrl': 'https://imgur.com/JGqeHb2',
#     'thumbnail': 'https://i.imgur.com/JGqeHb2l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T07:07:47.084Z',
#     'updatedAt': '2020-12-21T10:13:21.728Z',
#     'width': 414,
#     'height': 310}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 278}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': True,
#   'layout': 'classic',
#   'pinnedType': 'dcard',
#   'pinnedPriority': 1608545601723,
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/JGqeHb2.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': 'https://megapx-assets.dcard.tw/images/26f3f586-a2bc-44c6-a685-8da4c85df595/full.png',
#   'verifiedBadge': True},
#  {'id': 235021477,
#   'title': '🔥#圖多#試色 MAC唇膏眼影底妝失心瘋',
#   'excerpt': '哈摟大家好！，今天是我隔離的最後一天了，來檢討的是我黑五沒忍住爆買了MAC，經典黑管唇膏打6折，其他全場7折！，我也默默刷了幾單，把想買的唇膏一次買齊了，還有新品的眼影跟唇膏也納入後宮，先從包裝粉粉的',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T05:05:27.545Z',
#   'updatedAt': '2020-12-21T06:22:01.027Z',
#   'commentCount': 12,
#   'likeCount': 204,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['分享', '試色', '唇彩', '眼影', '口紅'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '黑衣紅唇炸雞狂粉💋',
#   'department': 'alisacchen',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '72fe3682-9a3e-44ff-9a15-4075e0655b49',
#     'url': 'https://i.imgur.com/DoU1TZtl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/DoU1TZtl.jpg',
#     'thumbnail': 'https://i.imgur.com/DoU1TZtl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '72fe3682-9a3e-44ff-9a15-4075e0655b49',
#     'url': 'https://i.imgur.com/DoU1TZt.jpg',
#     'normalizedUrl': 'https://imgur.com/DoU1TZt',
#     'thumbnail': 'https://i.imgur.com/DoU1TZtl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'caaeb3eb-2aab-4552-9f19-7f22caf05315',
#     'url': 'https://i.imgur.com/jhRIUof.jpg',
#     'normalizedUrl': 'https://imgur.com/jhRIUof',
#     'thumbnail': 'https://i.imgur.com/jhRIUofl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '9d28c687-7cbf-4ad8-9b32-a9112399e75e',
#     'url': 'https://i.imgur.com/STQxv34.jpg',
#     'normalizedUrl': 'https://imgur.com/STQxv34',
#     'thumbnail': 'https://i.imgur.com/STQxv34l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'dccd876f-309e-4e9e-b471-85d4c0cad633',
#     'url': 'https://i.imgur.com/EQOSYvZ.jpg',
#     'normalizedUrl': 'https://imgur.com/EQOSYvZ',
#     'thumbnail': 'https://i.imgur.com/EQOSYvZl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '7378e1ad-75aa-4c7e-b6e0-1a9bc59768ef',
#     'url': 'https://i.imgur.com/TnPQqRF.jpg',
#     'normalizedUrl': 'https://imgur.com/TnPQqRF',
#     'thumbnail': 'https://i.imgur.com/TnPQqRFl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'dfdf43bb-b6bb-453f-abc1-f5265ae7934e',
#     'url': 'https://i.imgur.com/MvnP5Rv.jpg',
#     'normalizedUrl': 'https://imgur.com/MvnP5Rv',
#     'thumbnail': 'https://i.imgur.com/MvnP5Rvl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'f86204a8-69da-493b-b7fb-49ef67c93639',
#     'url': 'https://i.imgur.com/MHaWnVX.jpg',
#     'normalizedUrl': 'https://imgur.com/MHaWnVX',
#     'thumbnail': 'https://i.imgur.com/MHaWnVXl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'bdf30e1d-7ef7-42e1-978c-abd6ad99a97c',
#     'url': 'https://i.imgur.com/FUk7kIG.jpg',
#     'normalizedUrl': 'https://imgur.com/FUk7kIG',
#     'thumbnail': 'https://i.imgur.com/FUk7kIGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '218f0861-7a88-4b66-9640-ee3641d7f79a',
#     'url': 'https://i.imgur.com/izUfqIo.jpg',
#     'normalizedUrl': 'https://imgur.com/izUfqIo',
#     'thumbnail': 'https://i.imgur.com/izUfqIol.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '1991ffff-97b1-4964-90f4-aa959701a86b',
#     'url': 'https://i.imgur.com/GZer7tf.jpg',
#     'normalizedUrl': 'https://imgur.com/GZer7tf',
#     'thumbnail': 'https://i.imgur.com/GZer7tfl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '7e976356-a05c-4ac6-9124-6f9f03d32384',
#     'url': 'https://i.imgur.com/9hxenQQ.jpg',
#     'normalizedUrl': 'https://imgur.com/9hxenQQ',
#     'thumbnail': 'https://i.imgur.com/9hxenQQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '4fd74493-8e3e-44ee-a2c5-6ceb7ca54949',
#     'url': 'https://i.imgur.com/RdqjlyY.jpg',
#     'normalizedUrl': 'https://imgur.com/RdqjlyY',
#     'thumbnail': 'https://i.imgur.com/RdqjlyYl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'b59d626f-cb8e-4349-9729-8b85c01a9298',
#     'url': 'https://i.imgur.com/ZczDIYb.jpg',
#     'normalizedUrl': 'https://imgur.com/ZczDIYb',
#     'thumbnail': 'https://i.imgur.com/ZczDIYbl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 2771,
#     'height': 2771},
#    {'id': '5ed387bc-c57c-43dc-a126-7a022918f04d',
#     'url': 'https://i.imgur.com/xEw3UyI.jpg',
#     'normalizedUrl': 'https://imgur.com/xEw3UyI',
#     'thumbnail': 'https://i.imgur.com/xEw3UyIl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 2771,
#     'height': 2771},
#    {'id': '97631cf5-f254-49cb-b588-cf654195fef7',
#     'url': 'https://i.imgur.com/HtMgiov.jpg',
#     'normalizedUrl': 'https://imgur.com/HtMgiov',
#     'thumbnail': 'https://i.imgur.com/HtMgiovl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3118,
#     'height': 3118},
#    {'id': '7c0dd176-ffab-43ea-a6ba-2d66c8d50982',
#     'url': 'https://i.imgur.com/9Thwtmw.jpg',
#     'normalizedUrl': 'https://imgur.com/9Thwtmw',
#     'thumbnail': 'https://i.imgur.com/9Thwtmwl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 2425,
#     'height': 2425},
#    {'id': '6bea7d79-3f6a-4c31-9e0c-3824b53fca33',
#     'url': 'https://i.imgur.com/eACqpeF.jpg',
#     'normalizedUrl': 'https://imgur.com/eACqpeF',
#     'thumbnail': 'https://i.imgur.com/eACqpeFl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3118,
#     'height': 3118},
#    {'id': 'fc273d1c-0ea5-4f4d-bb96-a011f485c481',
#     'url': 'https://i.imgur.com/QPbLf7W.jpg',
#     'normalizedUrl': 'https://imgur.com/QPbLf7W',
#     'thumbnail': 'https://i.imgur.com/QPbLf7Wl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3118,
#     'height': 3118},
#    {'id': 'c18b6743-5bda-4942-adea-e10d2fa02691',
#     'url': 'https://i.imgur.com/viH2hol.jpg',
#     'normalizedUrl': 'https://imgur.com/viH2hol',
#     'thumbnail': 'https://i.imgur.com/viH2holl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': '24799630-6c44-4fd4-a914-b686a761b0c2',
#     'url': 'https://i.imgur.com/4U5qeuX.jpg',
#     'normalizedUrl': 'https://imgur.com/4U5qeuX',
#     'thumbnail': 'https://i.imgur.com/4U5qeuXl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3464,
#     'height': 3464},
#    {'id': 'd831ab5d-6759-4011-9175-e63022599738',
#     'url': 'https://i.imgur.com/jODmfyT.jpg',
#     'normalizedUrl': 'https://imgur.com/jODmfyT',
#     'thumbnail': 'https://i.imgur.com/jODmfyTl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3226,
#     'height': 2419},
#    {'id': '7b5f4b64-d37f-444b-b58a-db79f0771a7e',
#     'url': 'https://i.imgur.com/upaxlcO.jpg',
#     'normalizedUrl': 'https://imgur.com/upaxlcO',
#     'thumbnail': 'https://i.imgur.com/upaxlcOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:05:27.545Z',
#     'updatedAt': '2020-12-21T06:22:01.027Z',
#     'width': 3226,
#     'height': 2419}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 204}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/DoU1TZt.jpg'},
#    {'url': 'https://i.imgur.com/jhRIUof.jpg'},
#    {'url': 'https://i.imgur.com/STQxv34.jpg'},
#    {'url': 'https://i.imgur.com/EQOSYvZ.jpg'},
#    {'url': 'https://i.imgur.com/TnPQqRF.jpg'},
#    {'url': 'https://i.imgur.com/MvnP5Rv.jpg'},
#    {'url': 'https://i.imgur.com/MHaWnVX.jpg'},
#    {'url': 'https://i.imgur.com/FUk7kIG.jpg'},
#    {'url': 'https://i.imgur.com/izUfqIo.jpg'},
#    {'url': 'https://i.imgur.com/GZer7tf.jpg'},
#    {'url': 'https://i.imgur.com/9hxenQQ.jpg'},
#    {'url': 'https://i.imgur.com/RdqjlyY.jpg'},
#    {'url': 'https://i.imgur.com/ZczDIYb.jpg'},
#    {'url': 'https://i.imgur.com/xEw3UyI.jpg'},
#    {'url': 'https://i.imgur.com/HtMgiov.jpg'},
#    {'url': 'https://i.imgur.com/9Thwtmw.jpg'},
#    {'url': 'https://i.imgur.com/eACqpeF.jpg'},
#    {'url': 'https://i.imgur.com/QPbLf7W.jpg'},
#    {'url': 'https://i.imgur.com/viH2hol.jpg'},
#    {'url': 'https://i.imgur.com/4U5qeuX.jpg'},
#    {'url': 'https://i.imgur.com/jODmfyT.jpg'},
#    {'url': 'https://i.imgur.com/upaxlcO.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235025010,
#   'title': '#吐槽大會 那些我2021絕對不會購入的東西🌚',
#   'excerpt': 'Hello又是我ʕ •ᴥ•ʔ 由於最近吐槽大會看太多了 我戲癮上身也很想來吐槽一下，所以今天來個不一樣的分享- 2020年度雷品分享ಥ_ಥ（ ･᷄ὢ･᷅ ），Declaration ：以上純粹我個人的使用',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T14:45:24.926Z',
#   'updatedAt': '2020-12-21T14:45:24.926Z',
#   'commentCount': 30,
#   'likeCount': 183,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['分享', '吐槽', '雷品'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '勸敗女王ʕ •ᴥ•ʔ',
#   'department': 'lalalafreak',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5b3d01ca-f199-46fe-b5ec-6a06b06e4f30',
#     'url': 'https://i.imgur.com/tkAx1BUl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/tkAx1BUl.jpg',
#     'thumbnail': 'https://i.imgur.com/tkAx1BUl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T14:45:24.926Z',
#     'updatedAt': '2020-12-21T14:45:24.926Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '5b3d01ca-f199-46fe-b5ec-6a06b06e4f30',
#     'url': 'https://i.imgur.com/tkAx1BU.jpg',
#     'normalizedUrl': 'https://imgur.com/tkAx1BU',
#     'thumbnail': 'https://i.imgur.com/tkAx1BUl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T14:45:24.926Z',
#     'updatedAt': '2020-12-21T14:45:24.926Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '1689ea4a-4183-4a03-8561-00bee7f766ea',
#     'url': 'https://i.imgur.com/IxppW32.jpg',
#     'normalizedUrl': 'https://imgur.com/IxppW32',
#     'thumbnail': 'https://i.imgur.com/IxppW32l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T14:45:24.926Z',
#     'updatedAt': '2020-12-21T14:45:24.926Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '5a3edb50-8303-42ce-9196-a9af95204e4b',
#     'url': 'https://i.imgur.com/sAlJx7F.jpg',
#     'normalizedUrl': 'https://imgur.com/sAlJx7F',
#     'thumbnail': 'https://i.imgur.com/sAlJx7Fl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T14:45:24.926Z',
#     'updatedAt': '2020-12-21T14:45:24.926Z',
#     'width': 1125,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 181},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['吐槽大會'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/tkAx1BU.jpg'},
#    {'url': 'https://i.imgur.com/IxppW32.jpg'},
#    {'url': 'https://i.imgur.com/sAlJx7F.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235022346,
#   'title': '#分享 日常上學眼妝٩(˃̶͈̀௰˂̶͈́)و',
#   'excerpt': '大家午安，今天想跟大家分享三個日常上學眼妝，第一跟第二個都是用NYX的warm neutrals這盤十六色眼影完成～這真的很好用而且也不會亂飛粉！，這是第一個眼妝完妝照，我是用1打底整個眼窩，2用來打',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T07:37:10.545Z',
#   'updatedAt': '2020-12-21T07:37:10.545Z',
#   'commentCount': 10,
#   'likeCount': 161,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['眼妝', '分享'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '可可C',
#   'department': 'keke_c',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6ce0a2a0-146e-40c6-a453-bacedbfa0abb',
#     'url': 'https://i.imgur.com/X6rUJDwl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/X6rUJDwl.jpg',
#     'thumbnail': 'https://i.imgur.com/X6rUJDwl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '6ce0a2a0-146e-40c6-a453-bacedbfa0abb',
#     'url': 'https://i.imgur.com/X6rUJDw.jpg',
#     'normalizedUrl': 'https://imgur.com/X6rUJDw',
#     'thumbnail': 'https://i.imgur.com/X6rUJDwl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '63efa9b6-e54d-42e8-88aa-62d8e77f811f',
#     'url': 'https://i.imgur.com/09dGYlZ.jpg',
#     'normalizedUrl': 'https://imgur.com/09dGYlZ',
#     'thumbnail': 'https://i.imgur.com/09dGYlZl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 1818,
#     'height': 1818},
#    {'id': 'cd95d0b8-c73c-4f9d-b3cf-871f04c5a1ff',
#     'url': 'https://i.imgur.com/oj37R3f.jpg',
#     'normalizedUrl': 'https://imgur.com/oj37R3f',
#     'thumbnail': 'https://i.imgur.com/oj37R3fl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '6ca41a31-e2ad-4749-a792-b2aebd269f12',
#     'url': 'https://i.imgur.com/RLH7lWJ.jpg',
#     'normalizedUrl': 'https://imgur.com/RLH7lWJ',
#     'thumbnail': 'https://i.imgur.com/RLH7lWJl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'b7f0a77d-002a-4398-8e25-7167e9d70b4a',
#     'url': 'https://i.imgur.com/Fs62dKc.jpg',
#     'normalizedUrl': 'https://imgur.com/Fs62dKc',
#     'thumbnail': 'https://i.imgur.com/Fs62dKcl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 1818,
#     'height': 1818},
#    {'id': 'e3e26caa-a5f8-4f20-b9f5-5547f016455d',
#     'url': 'https://i.imgur.com/CA5kq4x.jpg',
#     'normalizedUrl': 'https://imgur.com/CA5kq4x',
#     'thumbnail': 'https://i.imgur.com/CA5kq4xl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'b1402b3f-b3e6-4846-993d-7d6d25dd374c',
#     'url': 'https://i.imgur.com/NFpNp7v.jpg',
#     'normalizedUrl': 'https://imgur.com/NFpNp7v',
#     'thumbnail': 'https://i.imgur.com/NFpNp7vl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T07:37:10.545Z',
#     'updatedAt': '2020-12-21T07:37:10.545Z',
#     'width': 2000,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 159},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/X6rUJDw.jpg'},
#    {'url': 'https://i.imgur.com/09dGYlZ.jpg'},
#    {'url': 'https://i.imgur.com/oj37R3f.jpg'},
#    {'url': 'https://i.imgur.com/RLH7lWJ.jpg'},
#    {'url': 'https://i.imgur.com/Fs62dKc.jpg'},
#    {'url': 'https://i.imgur.com/CA5kq4x.jpg'},
#    {'url': 'https://i.imgur.com/NFpNp7v.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235021551,
#   'title': '#分享 來一朵煙灰玫瑰，HERA #499',
#   'excerpt': '嗨嗨大家好～～先來一張人間香奈兒當鎮樓圖（⁎⁍̴̛ᴗ⁍̴̛⁎），是滴！今天要分享的是煎妮代言的HERA，海報色#499 ROSY SUEDE，在小紅書上被燒到，雖然小紅書看試色要打八折，但還是下手叻！一些衝動',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T05:16:38.008Z',
#   'updatedAt': '2020-12-21T05:19:09.051Z',
#   'commentCount': 11,
#   'likeCount': 155,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['分享', '試色', '唇彩'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '桑🍊',
#   'department': 'sun.jyu',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '02e66baa-a97e-4118-978e-5cf864dd7916',
#     'url': 'https://i.imgur.com/6QERC2Wl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/6QERC2Wl.jpg',
#     'thumbnail': 'https://i.imgur.com/6QERC2Wl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 750,
#     'height': 940},
#    {'id': '02e66baa-a97e-4118-978e-5cf864dd7916',
#     'url': 'https://i.imgur.com/6QERC2W.jpg',
#     'normalizedUrl': 'https://imgur.com/6QERC2W',
#     'thumbnail': 'https://i.imgur.com/6QERC2Wl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 750,
#     'height': 940},
#    {'id': 'cfeb0da1-fcc5-4aa4-8002-349866d9fc6b',
#     'url': 'https://i.imgur.com/mzEHs5Z.jpg',
#     'normalizedUrl': 'https://imgur.com/mzEHs5Z',
#     'thumbnail': 'https://i.imgur.com/mzEHs5Zl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 800,
#     'height': 800},
#    {'id': '3d87bae8-d6aa-4602-a329-7df48dc8d74f',
#     'url': 'https://i.imgur.com/f9fmKqR.jpg',
#     'normalizedUrl': 'https://imgur.com/f9fmKqR',
#     'thumbnail': 'https://i.imgur.com/f9fmKqRl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 800,
#     'height': 800},
#    {'id': '24058130-6717-491b-ab66-5b7813dac704',
#     'url': 'https://i.imgur.com/CrCjDJZ.jpg',
#     'normalizedUrl': 'https://imgur.com/CrCjDJZ',
#     'thumbnail': 'https://i.imgur.com/CrCjDJZl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 800,
#     'height': 800},
#    {'id': 'bab79af3-8c67-4dfa-8607-ace00dca9c39',
#     'url': 'https://i.imgur.com/Re42kSD.jpg',
#     'normalizedUrl': 'https://imgur.com/Re42kSD',
#     'thumbnail': 'https://i.imgur.com/Re42kSDl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T05:16:38.008Z',
#     'updatedAt': '2020-12-21T05:19:09.051Z',
#     'width': 798,
#     'height': 798}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 155}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/6QERC2W.jpg'},
#    {'url': 'https://i.imgur.com/mzEHs5Z.jpg'},
#    {'url': 'https://i.imgur.com/f9fmKqR.jpg'},
#    {'url': 'https://i.imgur.com/CrCjDJZ.jpg'},
#    {'url': 'https://i.imgur.com/Re42kSD.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235026845,
#   'title': '毛孔人必備的幾樣小可愛們✍',
#   'excerpt': '身為毛孔人，只要能讓毛孔縮小一咪咪，都是讓人值得開心的事情阿～自己除了有固定使用針對毛孔的保養品外，底妝產品也都會特別挑選，下雨宅在家就來分享一下我的幾款愛物們，先從我的日常保養開始介紹，Labo L',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-22T00:38:00.446Z',
#   'updatedAt': '2020-12-22T00:38:00.446Z',
#   'commentCount': 4,
#   'likeCount': 112,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['毛孔', '保養', '分享'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '銘傳大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'cf9d27e3-206e-486d-b1db-d787a20a7f13',
#     'url': 'https://i.imgur.com/to2aSsbl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/to2aSsbl.jpg',
#     'thumbnail': 'https://i.imgur.com/to2aSsbl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1478,
#     'height': 1108},
#    {'id': 'cf9d27e3-206e-486d-b1db-d787a20a7f13',
#     'url': 'https://i.imgur.com/to2aSsb.jpg',
#     'normalizedUrl': 'https://imgur.com/to2aSsb',
#     'thumbnail': 'https://i.imgur.com/to2aSsbl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1478,
#     'height': 1108},
#    {'id': 'ba7a1a48-376c-4801-b37a-eb5c4cd86c59',
#     'url': 'https://i.imgur.com/wTXQ8Tb.jpg',
#     'normalizedUrl': 'https://imgur.com/wTXQ8Tb',
#     'thumbnail': 'https://i.imgur.com/wTXQ8Tbl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1478,
#     'height': 1108},
#    {'id': '871a8e02-f431-43de-b741-e8e35db407e9',
#     'url': 'https://i.imgur.com/ZHvDXXs.jpg',
#     'normalizedUrl': 'https://imgur.com/ZHvDXXs',
#     'thumbnail': 'https://i.imgur.com/ZHvDXXsl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1708,
#     'height': 960},
#    {'id': '1a97a5b3-286d-41e8-ba09-5e0a253d4f9a',
#     'url': 'https://i.imgur.com/P3Y6pEU.jpg',
#     'normalizedUrl': 'https://imgur.com/P3Y6pEU',
#     'thumbnail': 'https://i.imgur.com/P3Y6pEUl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1280,
#     'height': 1278},
#    {'id': '1ffd4b14-cbb5-4139-a09e-818a4f164f9d',
#     'url': 'https://i.imgur.com/IM9HhMY.jpg',
#     'normalizedUrl': 'https://imgur.com/IM9HhMY',
#     'thumbnail': 'https://i.imgur.com/IM9HhMYl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-22T00:38:00.446Z',
#     'updatedAt': '2020-12-22T00:38:00.446Z',
#     'width': 1108,
#     'height': 1478}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 112}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/to2aSsb.jpg'},
#    {'url': 'https://i.imgur.com/wTXQ8Tb.jpg'},
#    {'url': 'https://i.imgur.com/ZHvDXXs.jpg'},
#    {'url': 'https://i.imgur.com/P3Y6pEU.jpg'},
#    {'url': 'https://i.imgur.com/IM9HhMY.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235025318,
#   'title': '舊款焦糖拿鐵的替代品',
#   'excerpt': '在康是美快打烊的時候 衝了一波他們的99元唇膏，也不想造成店員困擾 於是也沒試色拿了一隻顏色看起來滿美的solone 經典極癮唇膏203就結帳，沒想到挖到寶了🤩，焦糖拿鐵新版的顏色我真的沒有很愛 整體',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T15:29:36.622Z',
#   'updatedAt': '2020-12-21T15:29:36.622Z',
#   'commentCount': 3,
#   'likeCount': 105,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['唇彩', '試色'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '大家都躲在鍵盤後',
#   'department': 'nomonxnolife',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '2d3263db-f20e-4cce-9785-e21999ee0ec9',
#     'url': 'https://i.imgur.com/8vvwMLRl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/8vvwMLRl.jpg',
#     'thumbnail': 'https://i.imgur.com/8vvwMLRl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T15:29:36.622Z',
#     'updatedAt': '2020-12-21T15:29:36.622Z',
#     'width': 3024,
#     'height': 4032},
#    {'id': '2d3263db-f20e-4cce-9785-e21999ee0ec9',
#     'url': 'https://i.imgur.com/8vvwMLR.jpg',
#     'normalizedUrl': 'https://imgur.com/8vvwMLR',
#     'thumbnail': 'https://i.imgur.com/8vvwMLRl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T15:29:36.622Z',
#     'updatedAt': '2020-12-21T15:29:36.622Z',
#     'width': 3024,
#     'height': 4032}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 105}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/8vvwMLR.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235021107,
#   'title': '🔥3CE官網九宮格眼影盤買一送一 RIGHT NOW!!!',
#   'excerpt': '就是現在！！！，官網聖誕優惠 11：00-15：00，今天是九宮格眼影盤/霧面唇釉，買一送一，等於一盤overtake只要590，新註冊會員官網送80摳優惠金，好像是滿千免運，只有買兩盤九宮格眼影也免',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': 235010128,
#   'createdAt': '2020-12-21T03:57:57.576Z',
#   'updatedAt': '2020-12-21T03:57:57.576Z',
#   'commentCount': 71,
#   'likeCount': 98,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['3CE', '眼影', '優惠情報'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '子木',
#   'department': 'l_e_e',
#   'replyTitle': '#情報 3CE 最佳產品1+1',
#   'mediaMeta': [{'id': 'd40ae3a2-982b-4521-8912-ec7d777efeb6',
#     'url': 'https://i.imgur.com/zwBIIjgl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/zwBIIjgl.jpg',
#     'thumbnail': 'https://i.imgur.com/zwBIIjgl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T03:57:57.576Z',
#     'updatedAt': '2020-12-21T03:57:57.576Z',
#     'width': 720,
#     'height': 2701},
#    {'id': 'd40ae3a2-982b-4521-8912-ec7d777efeb6',
#     'url': 'https://i.imgur.com/zwBIIjg.jpg',
#     'normalizedUrl': 'https://imgur.com/zwBIIjg',
#     'thumbnail': 'https://i.imgur.com/zwBIIjgl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T03:57:57.576Z',
#     'updatedAt': '2020-12-21T03:57:57.576Z',
#     'width': 720,
#     'height': 2701}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 97},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/zwBIIjg.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235023535,
#   'title': '#分享 ［長文］盲買🇰🇷韓國5支唇膏來跟你們分享囉～',
#   'excerpt': '🦖平常在滑IG的時候，常常會看到各國唇膏的試色照片，也在收藏裡儲存了一大堆唇膏名單，所以這次就想了新的企劃，嘗試盲買不同國家的唇膏來寫分享文章～先說這五支唇彩不是在同天時間拍攝，所以會有光線的落差，先',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T10:56:19.212Z',
#   'updatedAt': '2020-12-21T10:56:19.212Z',
#   'commentCount': 34,
#   'likeCount': 89,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['韓國', '唇膏', '分享', '試色', '唇彩'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '佛系唇模',
#   'department': 'male_lip_model',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4a03cfe9-e57f-4d2f-a345-9b4ad864890b',
#     'url': 'https://i.imgur.com/aQe1KsJl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/aQe1KsJl.jpg',
#     'thumbnail': 'https://i.imgur.com/aQe1KsJl.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '4a03cfe9-e57f-4d2f-a345-9b4ad864890b',
#     'url': 'https://i.imgur.com/aQe1KsJ.jpg',
#     'normalizedUrl': 'https://imgur.com/aQe1KsJ',
#     'thumbnail': 'https://i.imgur.com/aQe1KsJl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'c536a71e-9066-49f9-8bf4-86b48acf1640',
#     'url': 'https://i.imgur.com/3LqJxVN.jpg',
#     'normalizedUrl': 'https://imgur.com/3LqJxVN',
#     'thumbnail': 'https://i.imgur.com/3LqJxVNl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'd701df5e-9425-42f5-a990-c2c6b7060bdb',
#     'url': 'https://i.imgur.com/evlnjyx.jpg',
#     'normalizedUrl': 'https://imgur.com/evlnjyx',
#     'thumbnail': 'https://i.imgur.com/evlnjyxl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'f800fbfd-eb28-4bfe-b5e7-ad3fcb88c832',
#     'url': 'https://i.imgur.com/qpRd4Fx.jpg',
#     'normalizedUrl': 'https://imgur.com/qpRd4Fx',
#     'thumbnail': 'https://i.imgur.com/qpRd4Fxl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '5ffe9a0d-9ac5-45ff-99b4-3f4e377486e1',
#     'url': 'https://i.imgur.com/VGJlK7n.jpg',
#     'normalizedUrl': 'https://imgur.com/VGJlK7n',
#     'thumbnail': 'https://i.imgur.com/VGJlK7nl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '07187c25-8a11-4512-b9e5-eb60a0871bdb',
#     'url': 'https://i.imgur.com/ZeQflXS.jpg',
#     'normalizedUrl': 'https://imgur.com/ZeQflXS',
#     'thumbnail': 'https://i.imgur.com/ZeQflXSl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '1259e0d4-b096-4eb3-918f-e8e13cd4f8fc',
#     'url': 'https://i.imgur.com/rI1X65G.jpg',
#     'normalizedUrl': 'https://imgur.com/rI1X65G',
#     'thumbnail': 'https://i.imgur.com/rI1X65Gl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '67d71932-c315-4741-bfd4-d9ffd749ebda',
#     'url': 'https://i.imgur.com/D2BFtx2.jpg',
#     'normalizedUrl': 'https://imgur.com/D2BFtx2',
#     'thumbnail': 'https://i.imgur.com/D2BFtx2l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '2c989a4d-b02b-4c51-929b-00a4a7a3e38f',
#     'url': 'https://i.imgur.com/YO42Z9k.jpg',
#     'normalizedUrl': 'https://imgur.com/YO42Z9k',
#     'thumbnail': 'https://i.imgur.com/YO42Z9kl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '2889da43-6a74-439c-8b69-2d1fc349a295',
#     'url': 'https://i.imgur.com/w6v90qU.jpg',
#     'normalizedUrl': 'https://imgur.com/w6v90qU',
#     'thumbnail': 'https://i.imgur.com/w6v90qUl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'cbd718bf-013d-4a73-bb2d-0ea8fdc96b3d',
#     'url': 'https://i.imgur.com/9hTOEE8.jpg',
#     'normalizedUrl': 'https://imgur.com/9hTOEE8',
#     'thumbnail': 'https://i.imgur.com/9hTOEE8l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '12f44e58-0377-44d8-b955-89588bd4d120',
#     'url': 'https://i.imgur.com/HwLRH9y.jpg',
#     'normalizedUrl': 'https://imgur.com/HwLRH9y',
#     'thumbnail': 'https://i.imgur.com/HwLRH9yl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'c42bd2d3-4f88-451b-8f59-f873d8d83537',
#     'url': 'https://i.imgur.com/0UJ1Qbh.jpg',
#     'normalizedUrl': 'https://imgur.com/0UJ1Qbh',
#     'thumbnail': 'https://i.imgur.com/0UJ1Qbhl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '6851f147-960c-4a18-a28e-76340c4cb73d',
#     'url': 'https://i.imgur.com/m5zThRo.jpg',
#     'normalizedUrl': 'https://imgur.com/m5zThRo',
#     'thumbnail': 'https://i.imgur.com/m5zThRol.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '8bcc0b1a-7c2e-49fa-bf4e-cb701148fa2b',
#     'url': 'https://i.imgur.com/D8QUEm1.jpg',
#     'normalizedUrl': 'https://imgur.com/D8QUEm1',
#     'thumbnail': 'https://i.imgur.com/D8QUEm1l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'a6339758-b410-44e1-8ede-460de53eeb95',
#     'url': 'https://i.imgur.com/aOo9XlP.jpg',
#     'normalizedUrl': 'https://imgur.com/aOo9XlP',
#     'thumbnail': 'https://i.imgur.com/aOo9XlPl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '83eb3775-642d-4691-b031-606859ef5086',
#     'url': 'https://i.imgur.com/Hpjlr8V.jpg',
#     'normalizedUrl': 'https://imgur.com/Hpjlr8V',
#     'thumbnail': 'https://i.imgur.com/Hpjlr8Vl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '30a7213f-4ce9-4109-8837-582291ba7a39',
#     'url': 'https://i.imgur.com/leaoXwe.jpg',
#     'normalizedUrl': 'https://imgur.com/leaoXwe',
#     'thumbnail': 'https://i.imgur.com/leaoXwel.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '3f0eaf6a-8654-42dc-b9cc-80a6924a1d25',
#     'url': 'https://i.imgur.com/b2djRDQ.jpg',
#     'normalizedUrl': 'https://imgur.com/b2djRDQ',
#     'thumbnail': 'https://i.imgur.com/b2djRDQl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'a4cf7536-be1c-4959-8871-2ce37348ac55',
#     'url': 'https://i.imgur.com/I4Br4lm.jpg',
#     'normalizedUrl': 'https://imgur.com/I4Br4lm',
#     'thumbnail': 'https://i.imgur.com/I4Br4lml.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '1ceb5618-dc1f-403f-b35c-39282bef26f2',
#     'url': 'https://i.imgur.com/zOT25GR.jpg',
#     'normalizedUrl': 'https://imgur.com/zOT25GR',
#     'thumbnail': 'https://i.imgur.com/zOT25GRl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'd34c1211-3e81-46bc-b6b3-02f7eeb135b6',
#     'url': 'https://i.imgur.com/q3NtLBt.jpg',
#     'normalizedUrl': 'https://imgur.com/q3NtLBt',
#     'thumbnail': 'https://i.imgur.com/q3NtLBtl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '15ef8dd9-6a88-4bd6-b590-b333394c7fb3',
#     'url': 'https://i.imgur.com/YcQtfut.jpg',
#     'normalizedUrl': 'https://imgur.com/YcQtfut',
#     'thumbnail': 'https://i.imgur.com/YcQtfutl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '420a735c-d4f2-4cde-a64c-1d92faf2f709',
#     'url': 'https://i.imgur.com/tb1ckpx.jpg',
#     'normalizedUrl': 'https://imgur.com/tb1ckpx',
#     'thumbnail': 'https://i.imgur.com/tb1ckpxl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'd284a49e-f021-43eb-a63f-278ae1c70a28',
#     'url': 'https://i.imgur.com/EAfbOYM.jpg',
#     'normalizedUrl': 'https://imgur.com/EAfbOYM',
#     'thumbnail': 'https://i.imgur.com/EAfbOYMl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '30630abd-1a26-4de9-9f1e-90a76e8f1266',
#     'url': 'https://i.imgur.com/21kGLOL.jpg',
#     'normalizedUrl': 'https://imgur.com/21kGLOL',
#     'thumbnail': 'https://i.imgur.com/21kGLOLl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'eede956a-abb6-4f4b-a0f1-32228a9587a4',
#     'url': 'https://i.imgur.com/wbL47A5.jpg',
#     'normalizedUrl': 'https://imgur.com/wbL47A5',
#     'thumbnail': 'https://i.imgur.com/wbL47A5l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '102c9b12-243a-476c-8eb9-b01758a60a75',
#     'url': 'https://i.imgur.com/XIPoDmG.jpg',
#     'normalizedUrl': 'https://imgur.com/XIPoDmG',
#     'thumbnail': 'https://i.imgur.com/XIPoDmGl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '05865e84-40f8-4c98-8af6-fb9ee1848837',
#     'url': 'https://i.imgur.com/f6FFqEV.jpg',
#     'normalizedUrl': 'https://imgur.com/f6FFqEV',
#     'thumbnail': 'https://i.imgur.com/f6FFqEVl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'f4df9a85-858e-4bbf-8322-456f03a2abfa',
#     'url': 'https://i.imgur.com/PHQXkfG.jpg',
#     'normalizedUrl': 'https://imgur.com/PHQXkfG',
#     'thumbnail': 'https://i.imgur.com/PHQXkfGl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '62d3a837-3758-4858-9030-5a5a3e529307',
#     'url': 'https://i.imgur.com/IlzVjpY.jpg',
#     'normalizedUrl': 'https://imgur.com/IlzVjpY',
#     'thumbnail': 'https://i.imgur.com/IlzVjpYl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'cf7eb565-49db-40d3-abdc-5526a32b49f0',
#     'url': 'https://i.imgur.com/DrKJmhO.jpg',
#     'normalizedUrl': 'https://imgur.com/DrKJmhO',
#     'thumbnail': 'https://i.imgur.com/DrKJmhOl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'fcf4171d-4769-436b-9db5-cd0117b9ef39',
#     'url': 'https://i.imgur.com/kgQePDY.jpg',
#     'normalizedUrl': 'https://imgur.com/kgQePDY',
#     'thumbnail': 'https://i.imgur.com/kgQePDYl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '1aeb6d45-05fb-4534-9a01-6e1a62eb9230',
#     'url': 'https://i.imgur.com/nqaOi7l.jpg',
#     'normalizedUrl': 'https://imgur.com/nqaOi7l',
#     'thumbnail': 'https://i.imgur.com/nqaOi7ll.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T10:56:19.212Z',
#     'updatedAt': '2020-12-21T10:56:19.212Z',
#     'width': 2000,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 89}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/aQe1KsJ.jpg'},
#    {'url': 'https://i.imgur.com/3LqJxVN.jpg'},
#    {'url': 'https://i.imgur.com/evlnjyx.jpg'},
#    {'url': 'https://i.imgur.com/qpRd4Fx.jpg'},
#    {'url': 'https://i.imgur.com/VGJlK7n.jpg'},
#    {'url': 'https://i.imgur.com/ZeQflXS.jpg'},
#    {'url': 'https://i.imgur.com/rI1X65G.jpg'},
#    {'url': 'https://i.imgur.com/D2BFtx2.jpg'},
#    {'url': 'https://i.imgur.com/YO42Z9k.jpg'},
#    {'url': 'https://i.imgur.com/w6v90qU.jpg'},
#    {'url': 'https://i.imgur.com/9hTOEE8.jpg'},
#    {'url': 'https://i.imgur.com/HwLRH9y.jpg'},
#    {'url': 'https://i.imgur.com/0UJ1Qbh.jpg'},
#    {'url': 'https://i.imgur.com/m5zThRo.jpg'},
#    {'url': 'https://i.imgur.com/D8QUEm1.jpg'},
#    {'url': 'https://i.imgur.com/aOo9XlP.jpg'},
#    {'url': 'https://i.imgur.com/Hpjlr8V.jpg'},
#    {'url': 'https://i.imgur.com/leaoXwe.jpg'},
#    {'url': 'https://i.imgur.com/b2djRDQ.jpg'},
#    {'url': 'https://i.imgur.com/I4Br4lm.jpg'},
#    {'url': 'https://i.imgur.com/zOT25GR.jpg'},
#    {'url': 'https://i.imgur.com/q3NtLBt.jpg'},
#    {'url': 'https://i.imgur.com/YcQtfut.jpg'},
#    {'url': 'https://i.imgur.com/tb1ckpx.jpg'},
#    {'url': 'https://i.imgur.com/EAfbOYM.jpg'},
#    {'url': 'https://i.imgur.com/21kGLOL.jpg'},
#    {'url': 'https://i.imgur.com/wbL47A5.jpg'},
#    {'url': 'https://i.imgur.com/XIPoDmG.jpg'},
#    {'url': 'https://i.imgur.com/f6FFqEV.jpg'},
#    {'url': 'https://i.imgur.com/PHQXkfG.jpg'},
#    {'url': 'https://i.imgur.com/IlzVjpY.jpg'},
#    {'url': 'https://i.imgur.com/DrKJmhO.jpg'},
#    {'url': 'https://i.imgur.com/kgQePDY.jpg'},
#    {'url': 'https://i.imgur.com/nqaOi7l.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235025794,
#   'title': '#分享 護膚邀請 我在CHANEL把錢錢變成這樣',
#   'excerpt': '最近真的太忙了，導致之前買的東西都還沒來得及分享發文，但，這篇我一定要抽出時間先發🤣，前陣子我的CHANEL天使櫃姐曼曼問我最近有沒有空，因為他想邀請我去體驗他們家的護膚，我當下真的受寵若驚！！！，說',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T16:31:27.840Z',
#   'updatedAt': '2020-12-22T00:02:51.700Z',
#   'commentCount': 10,
#   'likeCount': 85,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['護膚', '保養', '乾肌', '面膜', '精華'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '摳摳🐰코코',
# ...
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T11:37:11.122Z',
#   'updatedAt': '2020-12-21T11:38:20.896Z',
#   'commentCount': 4,
#   'likeCount': 38,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['MAC', '護唇膏', '折扣碼', '美麗台'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '臺北市立大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'adee81be-82f5-4917-a087-d62c9c5891c0',
#     'url': 'https://i.imgur.com/aOaOfXal.jpg',
#     'normalizedUrl': 'https://i.imgur.com/aOaOfXal.jpg',
#     'thumbnail': 'https://i.imgur.com/aOaOfXal.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:37:11.122Z',
#     'updatedAt': '2020-12-21T11:38:20.896Z',
#     'width': 1850,
#     'height': 1198},
#    {'id': 'adee81be-82f5-4917-a087-d62c9c5891c0',
#     'url': 'https://i.imgur.com/aOaOfXa.png',
#     'normalizedUrl': 'https://imgur.com/aOaOfXa',
#     'thumbnail': 'https://i.imgur.com/aOaOfXal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:37:11.122Z',
#     'updatedAt': '2020-12-21T11:38:20.896Z',
#     'width': 1850,
#     'height': 1198},
#    {'id': '212ca15f-07e6-4aae-8d4f-0f264fdfece6',
#     'url': 'https://i.imgur.com/hqtuuQB.png',
#     'normalizedUrl': 'https://imgur.com/hqtuuQB',
#     'thumbnail': 'https://i.imgur.com/hqtuuQBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:37:11.122Z',
#     'updatedAt': '2020-12-21T11:38:20.896Z',
#     'width': 836,
#     'height': 1064}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 38}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['情報'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/aOaOfXa.png'},
#    {'url': 'https://i.imgur.com/hqtuuQB.png'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235023881,
#   'title': '#分享 愛用分享',
#   'excerpt': '大家好，第一次分享，從臉到身體都有，也算是紀錄我今年到底把錢都花在哪裡🧐。1️⃣ tin 魚子淨膚潔顏慕斯，我會根據皮膚的狀態來挑選當天要用的洗面產品，因為早上想偷懶，又不想用起泡網搓泡泡，就想要改換慕斯',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T11:50:07.810Z',
#   'updatedAt': '2020-12-21T14:11:06.045Z',
#   'commentCount': 8,
#   'likeCount': 36,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['愛用', '分享', '保養'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'Bugbug',
#   'department': 'cancerbug',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9f793b19-ca21-48f3-b57c-1b51538260b8',
#     'url': 'https://i.imgur.com/GjbWZbRl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/GjbWZbRl.jpg',
#     'thumbnail': 'https://i.imgur.com/GjbWZbRl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 1500,
#      'height': 2000}},
#    {'id': '9f793b19-ca21-48f3-b57c-1b51538260b8',
#     'url': 'https://i.imgur.com/GjbWZbR.jpg',
#     'normalizedUrl': 'https://imgur.com/GjbWZbR',
#     'thumbnail': 'https://i.imgur.com/GjbWZbRl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000,
#     'croppingWindow': {'anchorX': 0,
#      'anchorY': 0,
#      'width': 1500,
#      'height': 2000}},
#    {'id': 'acc2df72-655c-4d2e-81ab-d2a23c7160bf',
#     'url': 'https://i.imgur.com/JC7YRp6.jpg',
#     'normalizedUrl': 'https://imgur.com/JC7YRp6',
#     'thumbnail': 'https://i.imgur.com/JC7YRp6l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '5107b28c-089e-4316-924a-bf9c4433def2',
#     'url': 'https://i.imgur.com/MABqzCA.jpg',
#     'normalizedUrl': 'https://imgur.com/MABqzCA',
#     'thumbnail': 'https://i.imgur.com/MABqzCAl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '61ca5ed1-81c5-47e1-8a78-93532ea9a56c',
#     'url': 'https://i.imgur.com/Cgvr4g2.jpg',
#     'normalizedUrl': 'https://imgur.com/Cgvr4g2',
#     'thumbnail': 'https://i.imgur.com/Cgvr4g2l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'dde4cd05-9333-43e1-98e7-1040547285be',
#     'url': 'https://i.imgur.com/lYmCNfp.jpg',
#     'normalizedUrl': 'https://imgur.com/lYmCNfp',
#     'thumbnail': 'https://i.imgur.com/lYmCNfpl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '0a8af924-bade-4843-a63e-bfdb0f5ed5f0',
#     'url': 'https://i.imgur.com/nBENHxF.jpg',
#     'normalizedUrl': 'https://imgur.com/nBENHxF',
#     'thumbnail': 'https://i.imgur.com/nBENHxFl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'bc6b6d3a-6bf5-4fd7-a6e4-c111c2d38888',
#     'url': 'https://i.imgur.com/ghNbb5Z.jpg',
#     'normalizedUrl': 'https://imgur.com/ghNbb5Z',
#     'thumbnail': 'https://i.imgur.com/ghNbb5Zl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T11:50:07.810Z',
#     'updatedAt': '2020-12-21T14:11:06.045Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 36}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/GjbWZbR.jpg'},
#    {'url': 'https://i.imgur.com/JC7YRp6.jpg'},
#    {'url': 'https://i.imgur.com/MABqzCA.jpg'},
#    {'url': 'https://i.imgur.com/Cgvr4g2.jpg'},
#    {'url': 'https://i.imgur.com/lYmCNfp.jpg'},
#    {'url': 'https://i.imgur.com/nBENHxF.jpg'},
#    {'url': 'https://i.imgur.com/ghNbb5Z.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235024413,
#   'title': '#分享 12月戰利品',
#   'excerpt': '各位安妞，年底一推折扣，陸陸續續也買了一些東西，決定來分享一下！！！，首先是已經被我用掉好幾片的蒸氣眼罩，之前用過花王蒸氣眼罩，可能因為鼻子比較敏感，我覺得香味真的太重了！，根本沒辦法好好休息後來就都',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T13:18:26.438Z',
#   'updatedAt': '2020-12-21T13:18:26.438Z',
#   'commentCount': 13,
#   'likeCount': 34,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['保養', '分享', '刷具', '面膜'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '世新大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'fa8e5e37-7ba0-4ed8-9520-1c7ef9c19945',
#     'url': 'https://i.imgur.com/RQRdW6ul.jpg',
#     'normalizedUrl': 'https://i.imgur.com/RQRdW6ul.jpg',
#     'thumbnail': 'https://i.imgur.com/RQRdW6ul.jpg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 1477,
#     'height': 1108},
#    {'id': 'fa8e5e37-7ba0-4ed8-9520-1c7ef9c19945',
#     'url': 'https://i.imgur.com/RQRdW6u.jpg',
#     'normalizedUrl': 'https://imgur.com/RQRdW6u',
#     'thumbnail': 'https://i.imgur.com/RQRdW6ul.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 1477,
#     'height': 1108},
#    {'id': '8ffbaa74-34aa-447b-9287-6533a8d009ae',
#     'url': 'https://i.imgur.com/gJ5DO73.jpg',
#     'normalizedUrl': 'https://imgur.com/gJ5DO73',
#     'thumbnail': 'https://i.imgur.com/gJ5DO73l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 1477,
#     'height': 1108},
#    {'id': 'a31bfc6d-601c-427c-8a21-08c4d3f1ba43',
#     'url': 'https://i.imgur.com/l5WzvU2.jpg',
#     'normalizedUrl': 'https://imgur.com/l5WzvU2',
#     'thumbnail': 'https://i.imgur.com/l5WzvU2l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 1477,
#     'height': 1108},
#    {'id': '4651d8b3-7b84-48c1-bebb-9b0f5f7ac494',
#     'url': 'https://i.imgur.com/gRNNd39.jpg',
#     'normalizedUrl': 'https://imgur.com/gRNNd39',
#     'thumbnail': 'https://i.imgur.com/gRNNd39l.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 4160,
#     'height': 3120},
#    {'id': '05b53c15-dbae-4942-b1b5-59a423302905',
#     'url': 'https://i.imgur.com/oSkN0jj.jpg',
#     'normalizedUrl': 'https://imgur.com/oSkN0jj',
#     'thumbnail': 'https://i.imgur.com/oSkN0jjl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 4160,
#     'height': 3120},
#    {'id': '31703e51-9a83-4184-af95-43136fbab2ef',
#     'url': 'https://i.imgur.com/IVbpnnH.jpg',
#     'normalizedUrl': 'https://imgur.com/IVbpnnH',
#     'thumbnail': 'https://i.imgur.com/IVbpnnHl.jpg',
#     'type': 'image/imgur',
#     'tags': [],
#     'createdAt': '2020-12-21T13:18:26.438Z',
#     'updatedAt': '2020-12-21T13:18:26.438Z',
#     'width': 1477,
#     'height': 1108}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 34}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/RQRdW6u.jpg'},
#    {'url': 'https://i.imgur.com/gJ5DO73.jpg'},
#    {'url': 'https://i.imgur.com/l5WzvU2.jpg'},
#    {'url': 'https://i.imgur.com/gRNNd39.jpg'},
#    {'url': 'https://i.imgur.com/oSkN0jj.jpg'},
#    {'url': 'https://i.imgur.com/IVbpnnH.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235029001,
#   'title': '#情報 近期專櫃保養品試用資訊大蒐集',
#   'excerpt': '好像是聖誕節的緣故，最近試用品領取的活動超多的！，幫大家整理了一些領取專櫃試用包的活動，畢竟好人有好報 說不定可以因此告別水逆ʕ •ᴥ•ʔ，btw專櫃品牌保養品都好貴，所以我很堅持一定要先試用才敢購買',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-22T08:03:19.030Z',
#   'updatedAt': '2020-12-22T08:04:26.682Z',
#   'commentCount': 6,
#   'likeCount': 32,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['專櫃保養', '分享', '情報'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立臺北大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 32}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['情報'],
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235025212,
#   'title': '#分享 國產保養品心得老實說',
#   'excerpt': '2020年居然不知不覺又要結束了啊⋯⋯，這幾天在整理化妝櫃，把一些空盒空罐整理回收，順便用手機記事本紀錄了一下自己購入過的保養品，因為我實在買太多了～就挑了一些覺得可分享XD，如標題，決定介紹一些國產',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T15:14:09.387Z',
#   'updatedAt': '2020-12-21T15:14:09.387Z',
#   'commentCount': 3,
#   'likeCount': 30,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['保養品', '保養', '分享', '保濕', '痘痘'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '大葉大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 30}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['分享'],
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 235024398,
#   'title': '#情報 #有臉 露華濃Revlon #445柚色玫瑰🥀 $100',
#   'excerpt': '白光 i11 pro 外鏡原圖輸出，忘記帶唇膏出門 在門市遇到$100的小確幸\U0001f972，如果你想塗兩層，網購也有優惠哦，台北不要再下雨了啦，都快發霉了，（完）',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'cbd5285f-3cba-4bfc-86d0-1ab52d201459',
#   'replyId': None,
#   'createdAt': '2020-12-21T13:15:04.418Z',
#   'updatedAt': '2020-12-21T13:16:34.450Z',
#   'commentCount': 7,
#   'likeCount': 30,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['露華濃', '玫瑰', '試色', '口紅', '唇彩'],
#   'meta': {'layout': 'classic'},
#   'forumName': '美妝',
#   'forumAlias': 'makeup',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '安追啊🥘Andrea',
#   'department': 'viviennehuhu',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '2d84aa03-1e7f-4a71-b468-c2d2c13c0189',
#     'url': 'https://i.imgur.com/5IGx8K1l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/5IGx8K1l.jpg',
#     'thumbnail': 'https://i.imgur.com/5IGx8K1l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T13:15:04.418Z',
#     'updatedAt': '2020-12-21T13:16:34.450Z',
#     'width': 2000,
#     'height': 1999},
#    {'id': '2d84aa03-1e7f-4a71-b468-c2d2c13c0189',
#     'url': 'https://i.imgur.com/5IGx8K1.jpg',
#     'normalizedUrl': 'https://imgur.com/5IGx8K1',
#     'thumbnail': 'https://i.imgur.com/5IGx8K1l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T13:15:04.418Z',
#     'updatedAt': '2020-12-21T13:16:34.450Z',
#     'width': 2000,
#     'height': 1999},
#    {'id': 'bc97e306-10a3-400a-9a34-5ff958569d64',
#     'url': 'https://i.imgur.com/7E60Xzb.jpg',
#     'normalizedUrl': 'https://imgur.com/7E60Xzb',
#     'thumbnail': 'https://i.imgur.com/7E60Xzbl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T13:15:04.418Z',
#     'updatedAt': '2020-12-21T13:16:34.450Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': '0f041fda-67cd-4f58-a99d-53e55f42b656',
#     'url': 'https://i.imgur.com/jzpSFam.jpg',
#     'normalizedUrl': 'https://imgur.com/jzpSFam',
#     'thumbnail': 'https://i.imgur.com/jzpSFaml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-12-21T13:15:04.418Z',
#     'updatedAt': '2020-12-21T13:16:34.450Z',
#     'width': 1125,
#     'height': 1730}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 30}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'spoilerAlert': False,
#   'categories': ['情報'],
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/5IGx8K1.jpg'},
#    {'url': 'https://i.imgur.com/7E60Xzb.jpg'},
#    {'url': 'https://i.imgur.com/jzpSFam.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False}]

# %%
# 一次讀取100篇最熱門的文章
url = 'http://dcard.tw/_api/forums/makeup/posts?popular=true'
resq = requests.get(url)
rejs = resq.json()
df = pd.DataFrame()
for i in range(len(rejs)):
    df = df.append(Crawl(rejs[i]['id']),ignore_index=True)
print(df.shape)
df

# %% [markdown]
# 欄位	說明	備註
# ID	編號
# title	標題
# content	內容
# excerpt	摘要
# createdAt	發布時間
# updatedAt	更新時間
# commentCount	留言數
# forumName	分類	中文
# forumAlias	分類	英文
# gender	性別
# likeCount	心情數量
# reactions	心情細項	把以上心情細分為「愛心」、「哈哈」、「跪」、「森77」、「驚訝」等類型
# topics	標籤

# %%
for k in range(0,10):
    post_data={
        "before":a[-1][9:18],
        "limit":"30",
        "popular":"true"
    }
    r = p.get("https://www.dcard.tw/_api/forums/makeup/posts",
              params=post_data, 
              headers = { "Referer": "https://www.dcard.tw/", 
                         "User-Agent": "Mozilla/5.0" })
    ##
    data2 = json.loads(r.text)
    for u in range(len(data2)):
        #Temporary_url = "/f/makeup/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
        Temporary_url = str(data2[u]["id"])
        a.append(Temporary_url)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-7295110b727c> in <module>
#      13     for u in range(len(data2)):
#      14         #Temporary_url = "/f/makeup/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
# ---> 15         Temporary_url = str(data2[u]["id"])
#      16         a.append(Temporary_url)
#
# KeyError: 0

# %%
for k in range(0,10):
    post_data={
        "before":a[-1][9:18],
        "limit":"30",
        "popular":"true"
    }
    r = p.get("https://www.dcard.tw/_api/forums/makeup/posts",
              params=post_data, 
              headers = { "Referer": "https://www.dcard.tw/", 
                         "User-Agent": "Mozilla/5.0" })
    ##
    data2 = json.loads(r.text)
data2
# Out:
# {'error': 1107, 'message': '"before" must be a number', 'field': 'before'}

# %%
for k in range(0,10):
    post_data={
        "before":a[-1][9:18],
        "limit":"30",
        "popular":"true"
    }
    r = p.get("https://www.dcard.tw/_api/forums/pet/posts",
              params=post_data, 
              headers = { "Referer": "https://www.dcard.tw/", "User-Agent": "Mozilla/5.0" })
    data2 = json.loads(r.text)
    for u in range(len(data2)):
        Temporary_url = "/f/pet/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
        a.append(Temporary_url)
j=0 #為了印頁數
q=0 #為了印張數

# %%
# for k in range(0,10):
#     post_data={
#         "before":a[-1][9:18],
#         "limit":"30",
#         "popular":"true"
#     }
#     r = p.get("https://www.dcard.tw/_api/forums/pet/posts",
#               params=post_data, headers = { "Referer": "https://www.dcard.tw/", "User-Agent": "Mozilla/5.0" })

# %% [markdown]
# 發現GET來的檔案格式是JSON，那小編比較不會處理JSON怎辦?可以把他轉成Python就好啦，並組合好網址放進list

# %%
data2 = json.loads(r.text)
for u in range(len(data2)):
    Temporary_url = "/f/pet/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
    a.append(Temporary_url)

# %% [markdown]
# 接下來就是將list裡的URL，GET網頁出來

# %%
j=0
q=0
for i in a[2:]:
    url = "https://www.dcard.tw"+i
    j+=1
    print ("第",j,"頁的URL為:"+url)
    #file.write("temperature is {} wet is {}%\n".format(temperature, humidity))
    test.write("第 {} 頁的URL為: {} \n".format(j,url))
    url=requests.get(url)
    soup = BeautifulSoup(url.text,"html.parser")

# %% [markdown]
# 運用BeautifulSoup查看是否有符合圖片的標籤，然後運用上次所學，將圖片存檔

# %%
sel_jpg = soup.select("div.Post_content_NKEl9 div div div img.GalleryImage_image_3lGzO")
for c in sel_jpg:
    q+=1
    print("第",q,"張:",c["src"])
    test.write("%\n""第 {} 張: {} \n".format(q,c["src"])) 
    pic=requests.get(c["src"])
    img2 = pic.content
    pic_out = open("spider/pet/"+str(q)+".png",'wb')
    pic_out.write(img2)
    pic_out.close()

# %%
test.close()
print("爬蟲結束")

# %% [markdown]
# 完整的程式碼(可改range將文章變多)

# %%
#藉由首頁取得所有文章的URL
import requests
from bs4 import BeautifulSoup
import json

test = open("data/test.txt","w",encoding='UTF-8')


p = requests.Session()
url=requests.get("https://www.dcard.tw/f/pet")
soup = BeautifulSoup(url.text,"html.parser")
sel = soup.select("div.PostList_wrapper_2BLUM a.PostEntry_root_V6g0r")
a=[]
for s in sel:
    a.append(s["href"])
url = "https://www.dcard.tw"+ a[2]

for k in range(0,10):
        post_data={
            "before":a[-1][9:18],
            "limit":"30",
            "popular":"true"
        }
        r = p.get("https://www.dcard.tw/_api/forums/pet/posts",params=post_data, headers = { "Referer": "https://www.dcard.tw/", "User-Agent": "Mozilla/5.0" })
        data2 = json.loads(r.text)
        for u in range(len(data2)):
            Temporary_url = "/f/pet/p/"+ str(data2[u]["id"]) + "-" + str(data2[u]["title"].replace(" ","-"))
            a.append(Temporary_url)
j=0 #為了印頁數
q=0 #為了印張數
for i in a[2:]:
    url = "https://www.dcard.tw"+i
    j+=1
    print ("第",j,"頁的URL為:"+url)
    #file.write("temperature is {} wet is {}%\n".format(temperature, humidity))
    test.write("第 {} 頁的URL為: {} \n".format(j,url))
    url=requests.get(url)
    soup = BeautifulSoup(url.text,"html.parser")
    sel_jpg = soup.select("div.Post_content_NKEl9 div div div img.GalleryImage_image_3lGzO")
    for c in sel_jpg:
        q+=1
        print("第",q,"張:",c["src"])
        test.write("%\n""第 {} 張: {} \n".format(q,c["src"])) 
        pic=requests.get(c["src"])
        img2 = pic.content
        pic_out = open("spider/pet/"+str(q)+".png",'wb')
        pic_out.write(img2)
        pic_out.close()

test.close()
print("爬蟲結束")
